# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
import os
source_directory = '/content/drive/MyDrive/output'
destination_directory = '/content/food_v5/main'

if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

shutil.copytree(source_directory, destination_directory, dirs_exist_ok=True)

print(f"Files from {source_directory} have been copied to {destination_directory}")
# Out:
# Files from /content/drive/MyDrive/output have been copied to /content/food_v5/main

# %%
rar_file_path = '/content/main.rar'
output_directory = '/content/food_v5/main'
# !unrar x -y {rar_file_path} {output_directory}
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/main.rar
#
# Creating    /content/food_v5/main/temp                                OK
# Creating    /content/food_v5/main/temp/checkpoint                     OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1  OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalCategory  OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalCategory/weights  OK
#   OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalCategoryNoTransfer  OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalCategoryNoTransfer/weights  OK
#   OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalIngredients  OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalIngredients/weights  OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalIngredients/model  OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalIngredients/model/variables  OK
#   OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalCategory/model  OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalCategory/model/variables  OK
#   OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalCategoryNoTransfer/model  OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalCategoryNoTransfer/model/variables  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/food_v5/main/models                              OK
# Creating    /content/food_v5/main/models/logs                         OK
# Creating    /content/food_v5/main/models/logs/flat_efficientnetB1     OK
# Creating    /content/food_v5/main/models/logs/flat_efficientnetB1/finalIngredients  OK
# Creating    /content/food_v5/main/models/logs/flat_efficientnetB1/finalIngredients/train  OK
#   OK
# Creating    /content/food_v5/main/models/logs/flat_efficientnetB1/finalIngredients/validation  OK
#   OK
# Creating    /content/food_v5/main/models/logs/flat_efficientnetB1/finalCategory  OK
# Creating    /content/food_v5/main/models/logs/flat_efficientnetB1/finalCategory/train  OK
#   OK
# Creating    /content/food_v5/main/models/logs/flat_efficientnetB1/finalCategory/validation  OK
#   OK
# Creating    /content/food_v5/main/models/logs/flat_efficientnetB1/finalCategoryNoTransfer  OK
# Creating    /content/food_v5/main/models/logs/flat_efficientnetB1/finalCategoryNoTransfer/train  OK
#   OK
# Creating    /content/food_v5/main/models/logs/flat_efficientnetB1/finalCategoryNoTransfer/validation  OK
#   OK
# Creating    /content/food_v5/main/models/logs/flat_efficientnetB1/finalCategoryNoTransferFineTuned  OK
# Creating    /content/food_v5/main/models/logs/flat_efficientnetB1/finalCategoryNoTransferFineTuned/train  OK
#   OK
#   OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalCategory/model/assets  OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalCategoryNoTransfer/model/assets  OK
# Creating    /content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalIngredients/model/assets  OK
# All OK

# %%
import shutil
import os
source_directory = '/content/drive/MyDrive/food_v5'
destination_directory = '/content/food_v5'

if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

shutil.copytree(source_directory, destination_directory, dirs_exist_ok=True)

print(f"Files from {source_directory} have been copied to {destination_directory}")
# Out:
# Files from /content/drive/MyDrive/food_v5 have been copied to /content/food_v5

# %%
rar_file_path = '/content/food_v5/final-dataset/final-dataset.rar'
output_directory = '/content/food_v5/final-dataset'
# !unrar x -y {rar_file_path} {output_directory}
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# # Building Model

# %%
# !pip install import_ipynb ipynb
# Out:
# Collecting import_ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Collecting ipynb
#   Downloading ipynb-0.5.1-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (from import_ipynb) (7.34.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from import_ipynb) (5.10.4)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython->import_ipynb) (67.7.2)
# Collecting jedi>=0.16 (from IPython->import_ipynb)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython->import_ipynb) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython->import_ipynb) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython->import_ipynb) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython->import_ipynb) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython->import_ipynb) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython->import_ipynb) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython->import_ipynb) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython->import_ipynb) (4.9.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->import_ipynb) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->import_ipynb) (4.19.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from nbformat->import_ipynb) (5.7.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython->import_ipynb) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->import_ipynb) (0.18.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import_ipynb) (4.2.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython->import_ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import_ipynb) (0.2.13)
# Installing collected packages: jedi, ipynb, import_ipynb
# Successfully installed import_ipynb-0.1.4 ipynb-0.5.1 jedi-0.19.1

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from ipynb.fs.defs.data_pipeline import EXPORTED as data_pipeline
from tensorflow import keras
import json
import import_ipynb
from pathlib import Path
from types import SimpleNamespace
import pandas as pd
# Out:
# WARNING:absl:You use TensorFlow DType <dtype: 'string'> in tfds.features This will soon be deprecated in favor of NumPy DTypes. In the meantime it was converted to object.
# WARNING:absl:You use TensorFlow DType <dtype: 'float32'> in tfds.features This will soon be deprecated in favor of NumPy DTypes. In the meantime it was converted to float32.

# %% [markdown]
# # Loading builders for datasets

# %%
RECIPES5K_DIR = "/content/food_v5/final-dataset/tfrecord/recipes5k/1.0.0"
FOOD101_DIR = "/content/food_v5/final-dataset/tfrecord/food101/1.1.0"
NUTRITION5K_DIR = "/content/food_v5/final-dataset/tfrecord/nutrition5k/1.0.0"


recipes5k_food101_builder = tfds.builder_from_directories([RECIPES5K_DIR, FOOD101_DIR])
nutrition5k_builder = tfds.builder_from_directory(NUTRITION5K_DIR)

# %%
recipes5k_food101_builder.info.splits["train"].num_examples
# Out:
# 105826

# %%
nutrition5k_builder.info.splits["train"].num_examples
# Out:
# 271829

# %%
def encode_category_ingredients(category_tensor, ingredients_tensor):
    category = str(category_tensor.numpy(), "utf-8")
    ingredients = str(ingredients_tensor.numpy(), "utf-8")
    one_hot_category_tensor = (
        data_pipeline.one_hot_encoder.get_category_one_hot_encoding(category)
    )
    one_hot_ingredients_tensor = (
        data_pipeline.one_hot_encoder.get_ingredients_one_hot_encoding(
            ingredients.split(",")
        )
    )
    return (
        tf.constant(one_hot_category_tensor, dtype=tf.uint8),
        tf.constant(one_hot_ingredients_tensor, dtype=tf.uint8),
    )

# %%
def parse_function(x):
    encoded = tf.py_function(
        encode_category_ingredients,
        [x["category"], x["ingredients"]],
        [tf.uint8, tf.uint8],
    )
    return x["image_raw"], {
        "category_output": encoded[0],
        "calorie_output": x["calorie"],
        "carbs_output": x["carbs"],
        "protein_output": x["protein"],
        "fat_output": x["fat"],
        "ingredients_output": encoded[1],
    }

# %% [markdown]
# ## Creating dataset for training ingredients and nutrients only

# %%
# FULL DATASET
no_category_train, no_category_val = nutrition5k_builder.as_dataset(
    split=["train[:80%]", "train[80%:]"]
)

# %%
print(f"Total training size : {no_category_train.cardinality().numpy()}")
print(f"Total validation size : {no_category_val.cardinality().numpy()}")
# Out:
# Total training size : 217463
# Total validation size : 54366

# %%
BATCH_SIZE = 256
no_category_train = (
    no_category_train.map(parse_function).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
)
no_category_val = (
    no_category_val.map(parse_function).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# ## Creating dataset for training category, ingredients and nutrients

# %%
# FULL DATASET
(
    recipes5k_food101_train,
    recipes5k_food101_validation,
) = recipes5k_food101_builder.as_dataset(split=["train[:80%]", "train[80%:]"])

# Introduce the generic category, to avoid a bias dataset, only 1k images (average image per category) is taken from nutrition5k dataset
(nutrition5k_category_train, nutrition5k_category_val) = nutrition5k_builder.as_dataset(
    split=["train[:800]", "train[800:1000]"]
)

train_dataset = recipes5k_food101_train.concatenate(nutrition5k_category_train)
validation_dataset = recipes5k_food101_validation.concatenate(nutrition5k_category_val)

# %%
print(f"Total training size : {train_dataset.cardinality().numpy()}")
print(f"Total validation size : {validation_dataset.cardinality().numpy()}")
# Out:
# Total training size : 85461
# Total validation size : 21365

# %%
BATCH_SIZE = 256
train_dataset = (
    train_dataset.map(parse_function).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
)
validation_dataset = (
    validation_dataset.map(parse_function).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# # Model Development

# %%
class BaseModel:
    def __init__(
        self,
        input_shape,
        total_food_category,
        total_ingredients_category,
        name,
        model_config_name,
    ):
        self.input_shape = input_shape
        self.total_food_category = total_food_category
        self.total_ingredients_category = total_ingredients_category
        self.model = None
        self.name = name
        self.model_config_name = model_config_name

    def build(
        self,
        independent_category_units,
        independent_ingredients_units,
        independent_protein_units,
        independent_calorie_units,
        independent_carbs_units,
        independent_fat_units,
        shared_units,
    ):
        raise NotImplementedError

    def compile_model(self, optimizer):
        assert self.model is not None
        category_classification_loss = keras.losses.CategoricalCrossentropy()
        calorie_regression_loss = keras.losses.MeanAbsoluteError()
        carbs_regression_loss = keras.losses.MeanAbsoluteError()
        protein_regression_loss = keras.losses.MeanAbsoluteError()
        fat_regression_loss = keras.losses.MeanAbsoluteError()
        ingredient_multilabel_loss = keras.losses.BinaryCrossentropy()
        category_classification_metrics = (
            [
                keras.metrics.CategoricalAccuracy(name="acc"),
                keras.metrics.Precision(name="precision"),
                keras.metrics.Recall(name="recall"),
            ],
        )

        calorie_regression_metrics = [keras.metrics.MeanAbsoluteError(name="MAE")]
        carbs_regression_metrics = [keras.metrics.MeanAbsoluteError(name="MAE")]
        protein_regression_metrics = [keras.metrics.MeanAbsoluteError(name="MAE")]
        fat_regression_metrics = [keras.metrics.MeanAbsoluteError(name="MAE")]
        ingredient_multilabel_metrics = (
            [
                keras.metrics.Precision(name="precision"),
                keras.metrics.Recall(name="recall"),
            ],
        )
        category_classification_loss_weights = 1.0
        ingredient_multilabel_loss_weights = 1.0
        calorie_regression_loss_weights = 1.0
        carbs_regression_loss_weights = 1.0
        protein_regression_loss_weights = 1.0
        fat_regression_loss_weights = 1.0

        self.model.compile(
            optimizer=optimizer,
            loss={
                "category_output": category_classification_loss,
                "calorie_output": calorie_regression_loss,
                "carbs_output": carbs_regression_loss,
                "protein_output": protein_regression_loss,
                "fat_output": fat_regression_loss,
                "ingredients_output": ingredient_multilabel_loss,
            },
            metrics={
                "category_output": category_classification_metrics,
                "calorie_output": calorie_regression_metrics,
                "carbs_output": carbs_regression_metrics,
                "protein_output": protein_regression_metrics,
                "fat_output": fat_regression_metrics,
                "ingredients_output": ingredient_multilabel_metrics,
            },
            loss_weights={
                "category_output": category_classification_loss_weights,
                "calorie_output": calorie_regression_loss_weights,
                "carbs_output": carbs_regression_loss_weights,
                "protein_output": protein_regression_loss_weights,
                "fat_output": fat_regression_loss_weights,
                "ingredients_output": ingredient_multilabel_loss_weights,
            },
        )

    def freeze_category_classification_layers(self):
        assert self.model is not None
        submodel = self.model.get_layer("category_output")
        submodel.trainable = False

    def freeze_convolution_base(self):
        assert self.model is not None
        submodel = self.model.get_layer("efficientnetB1")
        submodel.trainable = False

    def get_callbacks(self):
        tensorboard_dir = f"/content/food_v5/main/models/logs/{self.name}/{self.model_config_name}"
        checkpoint_dir = f"/content/food_v5/main/temp/checkpoint/{self.name}/{self.model_config_name}"
        checkpoint_model_path = checkpoint_dir + "/model"
        checkpoint_weights_path = checkpoint_dir + "/weights/ckpt"
        checkpoint_model_callback = keras.callbacks.ModelCheckpoint(
            checkpoint_model_path, monitor="val_loss", save_best_only=True, mode="min"
        )
        checkpoint_weights_callback = keras.callbacks.ModelCheckpoint(
            checkpoint_weights_path,
            monitor="val_loss",
            save_best_only=True,
            save_weights_only=True,
            mode="min",
        )
        reduce_lr_callback = keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6, verbose=1
        )
        tensorboard_callback = keras.callbacks.TensorBoard(log_dir=tensorboard_dir)
        early_stopping_callback = keras.callbacks.EarlyStopping("val_loss", patience=8)
        return [
            tensorboard_callback,
            early_stopping_callback,
            checkpoint_model_callback,
            checkpoint_weights_callback,
            reduce_lr_callback,
        ]

    # Layers from bottom to top (classifier)  #
    def get_input_layer(self):
        return keras.Input(shape=self.input_shape)

    def get_augmentation_layers(self):
        input_layer = keras.layers.Input(shape=self.input_shape)
        augmentation_layer = keras.layers.RandomFlip()(input_layer)
        augmentation_layer = keras.layers.RandomRotation(0.2)(augmentation_layer)
        return keras.Model(
            inputs=input_layer, outputs=augmentation_layer, name="augmentation_layers"
        )

    def get_preprocess_layers(self, input_tensor):
        raise NotImplementedError

    def get_convolution_block(self):
        raise NotImplementedError

    def get_shared_layers(self, input_tensor, *num_units):
        input_layer = keras.layers.Input(shape=input_tensor.shape[1:])
        shared_layer = keras.layers.Flatten()(input_layer)
        shared_layer = keras.layers.Dense(
            num_units[0], activation="relu", name="shared_dense_1"
        )(shared_layer)
        shared_layer = keras.layers.BatchNormalization()(shared_layer)
        output_layer = keras.layers.Dropout(0.2)(shared_layer)
        return keras.Model(
            inputs=input_layer, outputs=output_layer, name="shared_layers"
        )

    def get_category_classification_layers(
        self, input_tensor, total_categories, *num_units
    ):
        input_layer = keras.layers.Input(shape=input_tensor.shape[1:])
        x = keras.layers.Dense(
            num_units[0], activation="relu", name="category_dense_1"
        )(input_layer)
        x = keras.layers.BatchNormalization()(x)
        category_classification_layer = keras.layers.Dense(
            total_categories, activation="softmax", name="category_output_layer"
        )(x)
        output_model = keras.Model(
            inputs=input_layer,
            outputs=category_classification_layer,
            name="category_output",
        )
        return output_model

    def get_calorie_regression_layers(self, input_tensor, *num_units):
        input_layer = keras.layers.Input(shape=input_tensor.shape[1:])
        x = keras.layers.Dense(num_units[0], activation="relu", name="calorie_dense_1")(
            input_layer
        )
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.Dense(num_units[1], activation="relu", name="calorie_dense_2")(
            x
        )
        x = keras.layers.BatchNormalization()(x)
        calorie_regression_layers = keras.layers.Dense(1, name="calorie_output_layer")(
            x
        )
        return keras.Model(
            inputs=input_layer, outputs=calorie_regression_layers, name="calorie_output"
        )

    def get_carbs_regression_layers(self, input_tensor, *num_units):
        input_layer = keras.layers.Input(shape=input_tensor.shape[1:])
        x = keras.layers.Dense(num_units[0], activation="relu", name="carbs_dense_1")(
            input_layer
        )
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.Dense(num_units[1], activation="relu", name="carbs_dense_2")(x)
        x = keras.layers.BatchNormalization()(x)
        carbs_regression_layers = keras.layers.Dense(1, name="carbs_output_layer")(x)
        return keras.Model(
            inputs=input_layer, outputs=carbs_regression_layers, name="carbs_output"
        )

    def get_protein_regression_layers(self, input_tensor, *num_units):
        input_layer = keras.layers.Input(shape=input_tensor.shape[1:])
        x = keras.layers.Dense(num_units[0], activation="relu", name="protein_dense_1")(
            input_layer
        )
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.Dense(num_units[1], activation="relu", name="protein_dense_2")(
            x
        )
        x = keras.layers.BatchNormalization()(x)
        protein_regression_layers = keras.layers.Dense(1, name="protein_output_layer")(
            x
        )
        return keras.Model(
            inputs=input_layer, outputs=protein_regression_layers, name="protein_output"
        )

    def get_fat_regression_layers(self, input_tensor, *num_units):
        input_layer = keras.layers.Input(shape=input_tensor.shape[1:])
        x = keras.layers.Dense(num_units[0], activation="relu", name="fat_dense_1")(
            input_layer
        )
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.Dense(num_units[1], activation="relu", name="fat_dense_2")(x)
        x = keras.layers.BatchNormalization()(x)
        fat_regression_layers = keras.layers.Dense(1, name="fat_output_layer")(x)
        return keras.Model(
            inputs=input_layer, outputs=fat_regression_layers, name="fat_output"
        )

    def get_ingredients_multilabel_layers(
        self, input_tensor, total_ingredients, *num_units
    ):
        input_layer = keras.layers.Input(shape=input_tensor.shape[1:])
        ingredients_multilabel_layers = keras.layers.Dense(
            num_units[0], activation="relu", name="ingredients_dense_1"
        )(input_layer)
        ingredients_multilabel_layers = keras.layers.BatchNormalization()(
            ingredients_multilabel_layers
        )
        ingredients_multilabel_layers = keras.layers.Dense(
            num_units[1], activation="relu", name="ingredients_dense_2"
        )(ingredients_multilabel_layers)
        ingredients_multilabel_layers = keras.layers.BatchNormalization()(
            ingredients_multilabel_layers
        )
        ingredients_multilabel_layers = keras.layers.Dense(
            num_units[2], activation="relu", name="ingredients_dense_3"
        )(ingredients_multilabel_layers)
        ingredients_multilabel_layers = keras.layers.BatchNormalization()(
            ingredients_multilabel_layers
        )
        output_layers = keras.layers.Dense(
            total_ingredients, activation="sigmoid", name="ingredients_output_layer"
        )(ingredients_multilabel_layers)
        return keras.Model(
            inputs=input_layer, outputs=output_layers, name="ingredients_output"
        )

    # End of layers  #

    def load_model(self, path):
        self.model = keras.models.load_model(path)

    def print_summary(self):
        assert (
            self.model is not None
        ), "Please run build_and_compile before printing summary."
        self.model.summary(expand_nested=True, show_trainable=True)

    def save_model(self, path):
        assert self.model is not None
        self.model.save(path, save_format="h5")

    def train_model(self, **kwargs):
        assert self.model is not None, "No model found."
        return self.model.fit(**kwargs, callbacks=self.get_callbacks())

    def unfreeze_category_classification_layers(self):
        assert self.model is not None
        submodel = self.model.get_layer("category_output")
        submodel.trainable = False

    def unfreeze_convolution_base(self, fine_tune_at=0):
        assert self.model is not None
        submodel = self.model.get_layer("efficientnetb1")
        submodel.trainable = True
        for layer in submodel.layers[:fine_tune_at]:
            layer.trainable = False

# %% [markdown]
# ## Flat Model

# %%
class FlatModel(BaseModel):
    def __init__(
        self,
        input_shape,
        total_food_category,
        total_ingredients_category,
        name,
        model_config_name,
    ):
        super().__init__(
            input_shape,
            total_food_category,
            total_ingredients_category,
            name,
            model_config_name,
        )

    def build(
        self,
        shared_units,
        independent_category_units,
        independent_protein_units,
        independent_fat_units,
        independent_carbs_units,
        independent_calorie_units,
        independent_ingredients_units,
    ):
        model_inputs = self.get_input_layer()
        prev_layer = self.get_augmentation_layers()(model_inputs)
        prev_layer = self.get_preprocess_layers(prev_layer)(prev_layer)
        prev_layer = self.get_convolution_block()(prev_layer)
        prev_layer = self.get_shared_layers(prev_layer, *shared_units)(prev_layer)
        category_classification_head = self.get_category_classification_layers(
            prev_layer, self.total_food_category, *independent_category_units
        )(prev_layer)
        ingredients_multilabel_head = self.get_ingredients_multilabel_layers(
            prev_layer, self.total_ingredients_category, *independent_ingredients_units
        )(prev_layer)
        calorie_regression_head = self.get_calorie_regression_layers(
            prev_layer, *independent_calorie_units
        )(prev_layer)
        carbs_regression_head = self.get_carbs_regression_layers(
            prev_layer, *independent_carbs_units
        )(prev_layer)
        protein_regression_head = self.get_protein_regression_layers(
            prev_layer, *independent_protein_units
        )(prev_layer)
        fat_regression_head = self.get_fat_regression_layers(
            prev_layer, *independent_fat_units
        )(prev_layer)

        model = keras.Model(
            inputs=model_inputs,
            outputs=[
                category_classification_head,
                ingredients_multilabel_head,
                calorie_regression_head,
                carbs_regression_head,
                protein_regression_head,
                fat_regression_head,
            ],
            name=self.name,
        )
        self.model = model

# %% [markdown]
# ### EfficientNetB1 (Best)

# %%
class FlatEfficientNetB1Model(FlatModel):
    def __init__(
        self,
        input_shape,
        total_food_category,
        total_ingredients_category,
        model_config_name,
    ):
        super().__init__(
            input_shape,
            total_food_category,
            total_ingredients_category,
            "flat_efficientnetB1",
            model_config_name,
        )

    def get_preprocess_layers(self, input_tensor):
        input_layer = keras.layers.Input(shape=input_tensor.shape[1:])
        output_layer = keras.applications.efficientnet.preprocess_input(input_layer)
        return keras.Model(
            inputs=input_layer, outputs=output_layer, name="preprocessing_layers"
        )

    def get_convolution_block(self):
        efficientnet_convolution_layers = (
            keras.applications.efficientnet.EfficientNetB1(
                input_shape=self.input_shape,
                include_top=False,
                weights="imagenet",
                pooling="avg",
            )
        )
        efficientnet_convolution_layers.trainable = False
        return efficientnet_convolution_layers

# %% [markdown]
# #### Train on ingredients dataset (nutrition5k)

# %%
flat_efficientnet = FlatEfficientNetB1Model(
    input_shape=(224, 224, 3),
    total_food_category=len(data_pipeline.one_hot_encoder.all_food_categories),
    total_ingredients_category=len(data_pipeline.one_hot_encoder.all_ingredients),
    model_config_name="finalIngredients",
)

flat_efficientnet.build(
    shared_units=[2048],
    independent_category_units=[512],
    independent_ingredients_units=[1024, 512, 256],
    independent_protein_units=[64, 32],
    independent_fat_units=[64, 32],
    independent_carbs_units=[64, 32],
    independent_calorie_units=[64, 32],
)
flat_efficientnet.freeze_category_classification_layers()
flat_efficientnet.compile_model(keras.optimizers.Adam())

flat_efficientnet.print_summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27018416/27018416 [==============================] - 0s 0us/step
# Model: "flat_efficientnetB1"
# _____________________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to                  Trainable
# =============================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []                            Y
#
#  augmentation_layers (Funct  (None, 224, 224, 3)          0         ['input_1[0][0]']             Y
#  ional)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_2 (InputLayer)       [(None, 224, 224, 3)]        0         []                            Y         |
# |                                                                                                           |
# | random_flip (RandomFlip)   (None, 224, 224, 3)          0         []                            Y         |
# |                                                                                                           |
# | random_rotation (RandomRo  (None, 224, 224, 3)          0         []                            Y         |
# | tation)                                                                                                   |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  preprocessing_layers (Func  (None, 224, 224, 3)          0         ['augmentation_layers[0][0]   Y
#  tional)                                                            ']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_3 (InputLayer)       [(None, 224, 224, 3)]        0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  efficientnetb1 (Functional  (None, 1280)                 6575239   ['preprocessing_layers[0][0   N
#  )                                                                  ]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_4 (InputLayer)       [(None, 224, 224, 3)]        0         []                            N         |
# |                                                                                                           |
# | rescaling (Rescaling)      (None, 224, 224, 3)          0         []                            N         |
# |                                                                                                           |
# | normalization (Normalizat  (None, 224, 224, 3)          7         []                            N         |
# | ion)                                                                                                      |
# |                                                                                                           |
# | rescaling_1 (Rescaling)    (None, 224, 224, 3)          0         []                            N         |
# |                                                                                                           |
# | stem_conv_pad (ZeroPaddin  (None, 225, 225, 3)          0         []                            N         |
# | g2D)                                                                                                      |
# |                                                                                                           |
# | stem_conv (Conv2D)         (None, 112, 112, 32)         864       []                            N         |
# |                                                                                                           |
# | stem_bn (BatchNormalizati  (None, 112, 112, 32)         128       []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | stem_activation (Activati  (None, 112, 112, 32)         0         []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | block1a_dwconv (Depthwise  (None, 112, 112, 32)         288       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block1a_bn (BatchNormaliz  (None, 112, 112, 32)         128       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1a_activation (Activ  (None, 112, 112, 32)         0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1a_se_squeeze (Globa  (None, 32)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block1a_se_reshape (Resha  (None, 1, 1, 32)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block1a_se_reduce (Conv2D  (None, 1, 1, 8)              264       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1a_se_expand (Conv2D  (None, 1, 1, 32)             288       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1a_se_excite (Multip  (None, 112, 112, 32)         0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block1a_project_conv (Con  (None, 112, 112, 16)         512       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block1a_project_bn (Batch  (None, 112, 112, 16)         64        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block1b_dwconv (Depthwise  (None, 112, 112, 16)         144       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block1b_bn (BatchNormaliz  (None, 112, 112, 16)         64        []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1b_activation (Activ  (None, 112, 112, 16)         0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1b_se_squeeze (Globa  (None, 16)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block1b_se_reshape (Resha  (None, 1, 1, 16)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block1b_se_reduce (Conv2D  (None, 1, 1, 4)              68        []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1b_se_expand (Conv2D  (None, 1, 1, 16)             80        []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1b_se_excite (Multip  (None, 112, 112, 16)         0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block1b_project_conv (Con  (None, 112, 112, 16)         256       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block1b_project_bn (Batch  (None, 112, 112, 16)         64        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block1b_drop (Dropout)     (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | block1b_add (Add)          (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | block2a_expand_conv (Conv  (None, 112, 112, 96)         1536      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2a_expand_bn (BatchN  (None, 112, 112, 96)         384       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2a_expand_activation  (None, 112, 112, 96)         0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2a_dwconv_pad (ZeroP  (None, 113, 113, 96)         0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block2a_dwconv (Depthwise  (None, 56, 56, 96)           864       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2a_bn (BatchNormaliz  (None, 56, 56, 96)           384       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2a_activation (Activ  (None, 56, 56, 96)           0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2a_se_squeeze (Globa  (None, 96)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2a_se_reshape (Resha  (None, 1, 1, 96)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2a_se_reduce (Conv2D  (None, 1, 1, 4)              388       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2a_se_expand (Conv2D  (None, 1, 1, 96)             480       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2a_se_excite (Multip  (None, 56, 56, 96)           0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2a_project_conv (Con  (None, 56, 56, 24)           2304      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2a_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2b_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2b_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2b_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2b_dwconv (Depthwise  (None, 56, 56, 144)          1296      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2b_bn (BatchNormaliz  (None, 56, 56, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2b_activation (Activ  (None, 56, 56, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2b_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2b_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2b_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2b_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2b_se_excite (Multip  (None, 56, 56, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2b_project_conv (Con  (None, 56, 56, 24)           3456      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2b_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2b_drop (Dropout)     (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2b_add (Add)          (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2c_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2c_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2c_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2c_dwconv (Depthwise  (None, 56, 56, 144)          1296      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2c_bn (BatchNormaliz  (None, 56, 56, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2c_activation (Activ  (None, 56, 56, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2c_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2c_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2c_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2c_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2c_se_excite (Multip  (None, 56, 56, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2c_project_conv (Con  (None, 56, 56, 24)           3456      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2c_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2c_drop (Dropout)     (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2c_add (Add)          (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block3a_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3a_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3a_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3a_dwconv_pad (ZeroP  (None, 59, 59, 144)          0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block3a_dwconv (Depthwise  (None, 28, 28, 144)          3600      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3a_bn (BatchNormaliz  (None, 28, 28, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3a_activation (Activ  (None, 28, 28, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3a_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3a_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3a_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3a_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3a_se_excite (Multip  (None, 28, 28, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3a_project_conv (Con  (None, 28, 28, 40)           5760      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3a_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3b_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3b_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3b_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3b_dwconv (Depthwise  (None, 28, 28, 240)          6000      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3b_bn (BatchNormaliz  (None, 28, 28, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3b_activation (Activ  (None, 28, 28, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3b_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3b_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3b_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3b_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3b_se_excite (Multip  (None, 28, 28, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3b_project_conv (Con  (None, 28, 28, 40)           9600      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3b_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3b_drop (Dropout)     (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3b_add (Add)          (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3c_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3c_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3c_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3c_dwconv (Depthwise  (None, 28, 28, 240)          6000      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3c_bn (BatchNormaliz  (None, 28, 28, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3c_activation (Activ  (None, 28, 28, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3c_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3c_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3c_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3c_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3c_se_excite (Multip  (None, 28, 28, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3c_project_conv (Con  (None, 28, 28, 40)           9600      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3c_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3c_drop (Dropout)     (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3c_add (Add)          (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block4a_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block4a_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block4a_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block4a_dwconv_pad (ZeroP  (None, 29, 29, 240)          0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block4a_dwconv (Depthwise  (None, 14, 14, 240)          2160      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block4a_bn (BatchNormaliz  (None, 14, 14, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4a_activation (Activ  (None, 14, 14, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4a_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block4a_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block4a_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4a_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4a_se_excite (Multip  (None, 14, 14, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block4a_project_conv (Con  (None, 14, 14, 80)           19200     []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block4a_project_bn (Batch  (None, 14, 14, 80)           320       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block4b_expand_conv (Conv  (None, 14, 14, 480)          38400     []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block4b_expand_bn (BatchN  (None, 14, 14, 480)          1920      []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block4b_expand_activation  (None, 14, 14, 480)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block4b_dwconv (Depthwise  (None, 14, 14, 480)          4320      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block4b_bn (BatchNormaliz  (None, 14, 14, 480)          1920      []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4b_activation (Activ  (None, 14, 14, 480)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4b_se_squeeze (Globa  (None, 480)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block4b_se_reshape (Resha  (None, 1, 1, 480)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block4b_se_reduce (Conv2D  (None, 1, 1, 20)             9620      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4b_se_expand (Conv2D  (None, 1, 1, 480)            10080     []                            N         |
# | )                                                                                                         |
# ...
# | block7b_project_conv (Con  (None, 7, 7, 320)            614400    []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block7b_project_bn (Batch  (None, 7, 7, 320)            1280      []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block7b_drop (Dropout)     (None, 7, 7, 320)            0         []                            N         |
# |                                                                                                           |
# | block7b_add (Add)          (None, 7, 7, 320)            0         []                            N         |
# |                                                                                                           |
# | top_conv (Conv2D)          (None, 7, 7, 1280)           409600    []                            N         |
# |                                                                                                           |
# | top_bn (BatchNormalizatio  (None, 7, 7, 1280)           5120      []                            N         |
# | n)                                                                                                        |
# |                                                                                                           |
# | top_activation (Activatio  (None, 7, 7, 1280)           0         []                            N         |
# | n)                                                                                                        |
# |                                                                                                           |
# | avg_pool (GlobalAveragePo  (None, 1280)                 0         []                            N         |
# | oling2D)                                                                                                  |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  shared_layers (Functional)  (None, 2048)                 2631680   ['efficientnetb1[0][0]']      Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_5 (InputLayer)       [(None, 1280)]               0         []                            Y         |
# |                                                                                                           |
# | flatten (Flatten)          (None, 1280)                 0         []                            Y         |
# |                                                                                                           |
# | shared_dense_1 (Dense)     (None, 2048)                 2623488   []                            Y         |
# |                                                                                                           |
# | batch_normalization (Batc  (None, 2048)                 8192      []                            Y         |
# | hNormalization)                                                                                           |
# |                                                                                                           |
# | dropout (Dropout)          (None, 2048)                 0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  category_output (Functiona  (None, 102)                  1103462   ['shared_layers[0][0]']       N
#  l)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_6 (InputLayer)       [(None, 2048)]               0         []                            N         |
# |                                                                                                           |
# | category_dense_1 (Dense)   (None, 512)                  1049088   []                            N         |
# |                                                                                                           |
# | batch_normalization_1 (Ba  (None, 512)                  2048      []                            N         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | category_output_layer (De  (None, 102)                  52326     []                            N         |
# | nse)                                                                                                      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  ingredients_output (Functi  (None, 1037)                 3027981   ['shared_layers[0][0]']       Y
#  onal)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_7 (InputLayer)       [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | ingredients_dense_1 (Dens  (None, 1024)                 2098176   []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_2 (Ba  (None, 1024)                 4096      []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | ingredients_dense_2 (Dens  (None, 512)                  524800    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_3 (Ba  (None, 512)                  2048      []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | ingredients_dense_3 (Dens  (None, 256)                  131328    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_4 (Ba  (None, 256)                  1024      []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | ingredients_output_layer   (None, 1037)                 266509    []                            Y         |
# | (Dense)                                                                                                   |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  calorie_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_8 (InputLayer)       [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | calorie_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_5 (Ba  (None, 64)                   256       []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | calorie_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_6 (Ba  (None, 32)                   128       []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | calorie_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  carbs_output (Functional)   (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_9 (InputLayer)       [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | carbs_dense_1 (Dense)      (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_7 (Ba  (None, 64)                   256       []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | carbs_dense_2 (Dense)      (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_8 (Ba  (None, 32)                   128       []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | carbs_output_layer (Dense  (None, 1)                    33        []                            Y         |
# | )                                                                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  protein_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_10 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | protein_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_9 (Ba  (None, 64)                   256       []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | protein_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_10 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  fat_output (Functional)     (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_11 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | fat_dense_1 (Dense)        (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_11 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_dense_2 (Dense)        (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_12 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_output_layer (Dense)   (None, 1)                    33        []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =============================================================================================================
# Total params: 13872894 (52.92 MB)
# Trainable params: 6185745 (23.60 MB)
# Non-trainable params: 7687149 (29.32 MB)
# _____________________________________________________________________________________________________________

# %%
flat_efficientnet.train_model(
    x=no_category_train,
    validation_data=no_category_val,
    epochs=5,
    verbose=2,
)
# Out:
# Epoch 1/5

# %% [markdown]
# #### Train on main dataset (recipes5k + food101 + nutrition5k) with weights transfer from ingredients dataset

# %%
flat_efficientnet = FlatEfficientNetB1Model(
    input_shape=(224, 224, 3),
    total_food_category=len(data_pipeline.one_hot_encoder.all_food_categories),
    total_ingredients_category=len(data_pipeline.one_hot_encoder.all_ingredients),
    model_config_name="finalCategory",
)

flat_efficientnet.load_model("/content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalIngredients/model")
flat_efficientnet.unfreeze_category_classification_layers()
flat_efficientnet.compile_model(keras.optimizers.Adam())

flat_efficientnet.print_summary()
# Out:
# Model: "flat_efficientnetB1"
# _____________________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to                  Trainable
# =============================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []                            Y
#
#  augmentation_layers (Funct  (None, 224, 224, 3)          0         ['input_1[0][0]']             Y
#  ional)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_2 (InputLayer)       [(None, 224, 224, 3)]        0         []                            Y         |
# |                                                                                                           |
# | random_flip (RandomFlip)   (None, 224, 224, 3)          0         []                            Y         |
# |                                                                                                           |
# | random_rotation (RandomRo  (None, 224, 224, 3)          0         []                            Y         |
# | tation)                                                                                                   |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  preprocessing_layers (Func  (None, 224, 224, 3)          0         ['augmentation_layers[0][0]   Y
#  tional)                                                            ']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_3 (InputLayer)       [(None, 224, 224, 3)]        0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  efficientnetb1 (Functional  (None, 1280)                 6575239   ['preprocessing_layers[0][0   N
#  )                                                                  ]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_4 (InputLayer)       [(None, 224, 224, 3)]        0         []                            Y         |
# |                                                                                                           |
# | rescaling (Rescaling)      (None, 224, 224, 3)          0         []                            N         |
# |                                                                                                           |
# | normalization (Normalizat  (None, 224, 224, 3)          7         []                            N         |
# | ion)                                                                                                      |
# |                                                                                                           |
# | stem_conv_pad (ZeroPaddin  (None, 225, 225, 3)          0         []                            N         |
# | g2D)                                                                                                      |
# |                                                                                                           |
# | stem_conv (Conv2D)         (None, 112, 112, 32)         864       []                            N         |
# |                                                                                                           |
# | stem_bn (BatchNormalizati  (None, 112, 112, 32)         128       []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | stem_activation (Activati  (None, 112, 112, 32)         0         []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | block1a_dwconv (Depthwise  (None, 112, 112, 32)         288       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block1a_bn (BatchNormaliz  (None, 112, 112, 32)         128       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1a_activation (Activ  (None, 112, 112, 32)         0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1a_se_squeeze (Globa  (None, 32)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block1a_se_reshape (Resha  (None, 1, 1, 32)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block1a_se_reduce (Conv2D  (None, 1, 1, 8)              264       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1a_se_expand (Conv2D  (None, 1, 1, 32)             288       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1a_se_excite (Multip  (None, 112, 112, 32)         0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block1a_project_conv (Con  (None, 112, 112, 16)         512       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block1a_project_bn (Batch  (None, 112, 112, 16)         64        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block1b_dwconv (Depthwise  (None, 112, 112, 16)         144       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block1b_bn (BatchNormaliz  (None, 112, 112, 16)         64        []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1b_activation (Activ  (None, 112, 112, 16)         0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1b_se_squeeze (Globa  (None, 16)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block1b_se_reshape (Resha  (None, 1, 1, 16)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block1b_se_reduce (Conv2D  (None, 1, 1, 4)              68        []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1b_se_expand (Conv2D  (None, 1, 1, 16)             80        []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1b_se_excite (Multip  (None, 112, 112, 16)         0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block1b_project_conv (Con  (None, 112, 112, 16)         256       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block1b_project_bn (Batch  (None, 112, 112, 16)         64        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block1b_drop (Dropout)     (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | block1b_add (Add)          (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | block2a_expand_conv (Conv  (None, 112, 112, 96)         1536      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2a_expand_bn (BatchN  (None, 112, 112, 96)         384       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2a_expand_activation  (None, 112, 112, 96)         0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2a_dwconv_pad (ZeroP  (None, 113, 113, 96)         0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block2a_dwconv (Depthwise  (None, 56, 56, 96)           864       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2a_bn (BatchNormaliz  (None, 56, 56, 96)           384       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2a_activation (Activ  (None, 56, 56, 96)           0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2a_se_squeeze (Globa  (None, 96)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2a_se_reshape (Resha  (None, 1, 1, 96)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2a_se_reduce (Conv2D  (None, 1, 1, 4)              388       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2a_se_expand (Conv2D  (None, 1, 1, 96)             480       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2a_se_excite (Multip  (None, 56, 56, 96)           0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2a_project_conv (Con  (None, 56, 56, 24)           2304      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2a_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2b_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2b_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2b_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2b_dwconv (Depthwise  (None, 56, 56, 144)          1296      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2b_bn (BatchNormaliz  (None, 56, 56, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2b_activation (Activ  (None, 56, 56, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2b_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2b_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2b_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2b_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2b_se_excite (Multip  (None, 56, 56, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2b_project_conv (Con  (None, 56, 56, 24)           3456      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2b_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2b_drop (Dropout)     (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2b_add (Add)          (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2c_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2c_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2c_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2c_dwconv (Depthwise  (None, 56, 56, 144)          1296      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2c_bn (BatchNormaliz  (None, 56, 56, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2c_activation (Activ  (None, 56, 56, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2c_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2c_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2c_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2c_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2c_se_excite (Multip  (None, 56, 56, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2c_project_conv (Con  (None, 56, 56, 24)           3456      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2c_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2c_drop (Dropout)     (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2c_add (Add)          (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block3a_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3a_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3a_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3a_dwconv_pad (ZeroP  (None, 59, 59, 144)          0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block3a_dwconv (Depthwise  (None, 28, 28, 144)          3600      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3a_bn (BatchNormaliz  (None, 28, 28, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3a_activation (Activ  (None, 28, 28, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3a_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3a_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3a_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3a_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3a_se_excite (Multip  (None, 28, 28, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3a_project_conv (Con  (None, 28, 28, 40)           5760      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3a_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3b_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3b_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3b_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3b_dwconv (Depthwise  (None, 28, 28, 240)          6000      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3b_bn (BatchNormaliz  (None, 28, 28, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3b_activation (Activ  (None, 28, 28, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3b_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3b_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3b_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3b_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3b_se_excite (Multip  (None, 28, 28, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3b_project_conv (Con  (None, 28, 28, 40)           9600      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3b_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3b_drop (Dropout)     (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3b_add (Add)          (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3c_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3c_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3c_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3c_dwconv (Depthwise  (None, 28, 28, 240)          6000      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3c_bn (BatchNormaliz  (None, 28, 28, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3c_activation (Activ  (None, 28, 28, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3c_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3c_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3c_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3c_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3c_se_excite (Multip  (None, 28, 28, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3c_project_conv (Con  (None, 28, 28, 40)           9600      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3c_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3c_drop (Dropout)     (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3c_add (Add)          (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block4a_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block4a_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block4a_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block4a_dwconv_pad (ZeroP  (None, 29, 29, 240)          0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block4a_dwconv (Depthwise  (None, 14, 14, 240)          2160      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block4a_bn (BatchNormaliz  (None, 14, 14, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4a_activation (Activ  (None, 14, 14, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4a_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block4a_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block4a_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4a_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4a_se_excite (Multip  (None, 14, 14, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block4a_project_conv (Con  (None, 14, 14, 80)           19200     []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block4a_project_bn (Batch  (None, 14, 14, 80)           320       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block4b_expand_conv (Conv  (None, 14, 14, 480)          38400     []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block4b_expand_bn (BatchN  (None, 14, 14, 480)          1920      []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block4b_expand_activation  (None, 14, 14, 480)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block4b_dwconv (Depthwise  (None, 14, 14, 480)          4320      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block4b_bn (BatchNormaliz  (None, 14, 14, 480)          1920      []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4b_activation (Activ  (None, 14, 14, 480)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4b_se_squeeze (Globa  (None, 480)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block4b_se_reshape (Resha  (None, 1, 1, 480)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block4b_se_reduce (Conv2D  (None, 1, 1, 20)             9620      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4b_se_expand (Conv2D  (None, 1, 1, 480)            10080     []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4b_se_excite (Multip  (None, 14, 14, 480)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# ...
# | block7b_project_conv (Con  (None, 7, 7, 320)            614400    []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block7b_project_bn (Batch  (None, 7, 7, 320)            1280      []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block7b_drop (Dropout)     (None, 7, 7, 320)            0         []                            N         |
# |                                                                                                           |
# | block7b_add (Add)          (None, 7, 7, 320)            0         []                            N         |
# |                                                                                                           |
# | top_conv (Conv2D)          (None, 7, 7, 1280)           409600    []                            N         |
# |                                                                                                           |
# | top_bn (BatchNormalizatio  (None, 7, 7, 1280)           5120      []                            N         |
# | n)                                                                                                        |
# |                                                                                                           |
# | top_activation (Activatio  (None, 7, 7, 1280)           0         []                            N         |
# | n)                                                                                                        |
# |                                                                                                           |
# | avg_pool (GlobalAveragePo  (None, 1280)                 0         []                            N         |
# | oling2D)                                                                                                  |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  shared_layers (Functional)  (None, 2048)                 2631680   ['efficientnetb1[0][0]']      Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_5 (InputLayer)       [(None, 1280)]               0         []                            Y         |
# |                                                                                                           |
# | flatten (Flatten)          (None, 1280)                 0         []                            Y         |
# |                                                                                                           |
# | shared_dense_1 (Dense)     (None, 2048)                 2623488   []                            Y         |
# |                                                                                                           |
# | batch_normalization (Batc  (None, 2048)                 8192      []                            Y         |
# | hNormalization)                                                                                           |
# |                                                                                                           |
# | dropout (Dropout)          (None, 2048)                 0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  category_output (Functiona  (None, 102)                  1103462   ['shared_layers[0][0]']       N
#  l)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_6 (InputLayer)       [(None, 2048)]               0         []                            N         |
# |                                                                                                           |
# | category_dense_1 (Dense)   (None, 512)                  1049088   []                            N         |
# |                                                                                                           |
# | batch_normalization_1 (Ba  (None, 512)                  2048      []                            N         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | category_output_layer (De  (None, 102)                  52326     []                            N         |
# | nse)                                                                                                      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  ingredients_output (Functi  (None, 1037)                 3027981   ['shared_layers[0][0]']       Y
#  onal)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_7 (InputLayer)       [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | ingredients_dense_1 (Dens  (None, 1024)                 2098176   []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_2 (Ba  (None, 1024)                 4096      []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | ingredients_dense_2 (Dens  (None, 512)                  524800    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_3 (Ba  (None, 512)                  2048      []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | ingredients_dense_3 (Dens  (None, 256)                  131328    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_4 (Ba  (None, 256)                  1024      []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | ingredients_output_layer   (None, 1037)                 266509    []                            Y         |
# | (Dense)                                                                                                   |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  calorie_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_8 (InputLayer)       [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | calorie_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_5 (Ba  (None, 64)                   256       []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | calorie_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_6 (Ba  (None, 32)                   128       []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | calorie_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  carbs_output (Functional)   (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_9 (InputLayer)       [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | carbs_dense_1 (Dense)      (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_7 (Ba  (None, 64)                   256       []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | carbs_dense_2 (Dense)      (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_8 (Ba  (None, 32)                   128       []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | carbs_output_layer (Dense  (None, 1)                    33        []                            Y         |
# | )                                                                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  protein_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_10 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | protein_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_9 (Ba  (None, 64)                   256       []                            Y         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | protein_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_10 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  fat_output (Functional)     (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_11 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | fat_dense_1 (Dense)        (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_11 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_dense_2 (Dense)        (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_12 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_output_layer (Dense)   (None, 1)                    33        []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =============================================================================================================
# Total params: 13872894 (52.92 MB)
# Trainable params: 6185745 (23.60 MB)
# Non-trainable params: 7687149 (29.32 MB)
# _____________________________________________________________________________________________________________

# %%
flat_efficientnet.train_model(
    x=train_dataset,
    validation_data=validation_dataset,
    epochs=5,
    verbose=2,
)
# Out:
# Epoch 1/5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-a720582705b5> in <cell line: 1>()
# ----> 1 flat_efficientnet.train_model(
#       2     x=train_dataset,
#       3     validation_data=validation_dataset,
#       4     epochs=5,
#       5     verbose=2,
#
# <ipython-input-23-ac51324a228a> in train_model(self, **kwargs)
#     280     def train_model(self, **kwargs):
#     281         assert self.model is not None, "No model found."
# --> 282         return self.model.fit(**kwargs, callbacks=self.get_callbacks())
#     283
#     284     def unfreeze_category_classification_layers(self):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1854                             pss_evaluation_shards=self._pss_evaluation_shards,
#    1855                         )
# -> 1856                     val_logs = self.evaluate(
#    1857                         x=val_x,
#    1858                         y=val_y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2294                         ):
#    2295                             callbacks.on_test_batch_begin(step)
# -> 2296                             logs = test_function_runner.run_step(
#    2297                                 dataset_or_iterator,
#    2298                                 data_handler,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in run_step(self, dataset_or_iterator, data_handler, step, unused_shards)
#    4106
#    4107     def run_step(self, dataset_or_iterator, data_handler, step, unused_shards):
# -> 4108         tmp_logs = self._function(dataset_or_iterator)
#    4109         if data_handler.should_sync:
#    4110             context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     875       # In this case we have not created variables on the first call. So we can
#     876       # run the first trace but we should fail if variables are created.
# --> 877       results = tracing_compilation.call_function(
#     878           args, kwds, self._variable_creation_config
#     879       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Train on main dataset (recipes5k + food101 + nutrition5k) without weights transfer

# %%
flat_efficientnet = FlatEfficientNetB1Model(
    input_shape=(224, 224, 3),
    total_food_category=len(data_pipeline.one_hot_encoder.all_food_categories),
    total_ingredients_category=len(data_pipeline.one_hot_encoder.all_ingredients),
    model_config_name="finalCategoryNoTransfer",
)

flat_efficientnet.build(
    shared_units=[2048],
    independent_category_units=[512],
    independent_ingredients_units=[1024, 512, 256],
    independent_protein_units=[64, 32],
    independent_fat_units=[64, 32],
    independent_carbs_units=[64, 32],
    independent_calorie_units=[64, 32],
)
flat_efficientnet.compile_model(keras.optimizers.Adam())

flat_efficientnet.print_summary()
# Out:
# Model: "flat_efficientnetB1"
# _____________________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to                  Trainable
# =============================================================================================================
#  input_12 (InputLayer)       [(None, 224, 224, 3)]        0         []                            Y
#
#  augmentation_layers (Funct  (None, 224, 224, 3)          0         ['input_12[0][0]']            Y
#  ional)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_13 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# |                                                                                                           |
# | random_flip_1 (RandomFlip  (None, 224, 224, 3)          0         []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | random_rotation_1 (Random  (None, 224, 224, 3)          0         []                            Y         |
# | Rotation)                                                                                                 |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  preprocessing_layers (Func  (None, 224, 224, 3)          0         ['augmentation_layers[0][0]   Y
#  tional)                                                            ']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_14 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  efficientnetb1 (Functional  (None, 1280)                 6575239   ['preprocessing_layers[0][0   N
#  )                                                                  ]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_15 (InputLayer)      [(None, 224, 224, 3)]        0         []                            N         |
# |                                                                                                           |
# | rescaling_2 (Rescaling)    (None, 224, 224, 3)          0         []                            N         |
# |                                                                                                           |
# | normalization_1 (Normaliz  (None, 224, 224, 3)          7         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | rescaling_3 (Rescaling)    (None, 224, 224, 3)          0         []                            N         |
# |                                                                                                           |
# | stem_conv_pad (ZeroPaddin  (None, 225, 225, 3)          0         []                            N         |
# | g2D)                                                                                                      |
# |                                                                                                           |
# | stem_conv (Conv2D)         (None, 112, 112, 32)         864       []                            N         |
# |                                                                                                           |
# | stem_bn (BatchNormalizati  (None, 112, 112, 32)         128       []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | stem_activation (Activati  (None, 112, 112, 32)         0         []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | block1a_dwconv (Depthwise  (None, 112, 112, 32)         288       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block1a_bn (BatchNormaliz  (None, 112, 112, 32)         128       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1a_activation (Activ  (None, 112, 112, 32)         0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1a_se_squeeze (Globa  (None, 32)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block1a_se_reshape (Resha  (None, 1, 1, 32)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block1a_se_reduce (Conv2D  (None, 1, 1, 8)              264       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1a_se_expand (Conv2D  (None, 1, 1, 32)             288       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1a_se_excite (Multip  (None, 112, 112, 32)         0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block1a_project_conv (Con  (None, 112, 112, 16)         512       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block1a_project_bn (Batch  (None, 112, 112, 16)         64        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block1b_dwconv (Depthwise  (None, 112, 112, 16)         144       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block1b_bn (BatchNormaliz  (None, 112, 112, 16)         64        []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1b_activation (Activ  (None, 112, 112, 16)         0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1b_se_squeeze (Globa  (None, 16)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block1b_se_reshape (Resha  (None, 1, 1, 16)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block1b_se_reduce (Conv2D  (None, 1, 1, 4)              68        []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1b_se_expand (Conv2D  (None, 1, 1, 16)             80        []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1b_se_excite (Multip  (None, 112, 112, 16)         0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block1b_project_conv (Con  (None, 112, 112, 16)         256       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block1b_project_bn (Batch  (None, 112, 112, 16)         64        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block1b_drop (Dropout)     (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | block1b_add (Add)          (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | block2a_expand_conv (Conv  (None, 112, 112, 96)         1536      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2a_expand_bn (BatchN  (None, 112, 112, 96)         384       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2a_expand_activation  (None, 112, 112, 96)         0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2a_dwconv_pad (ZeroP  (None, 113, 113, 96)         0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block2a_dwconv (Depthwise  (None, 56, 56, 96)           864       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2a_bn (BatchNormaliz  (None, 56, 56, 96)           384       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2a_activation (Activ  (None, 56, 56, 96)           0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2a_se_squeeze (Globa  (None, 96)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2a_se_reshape (Resha  (None, 1, 1, 96)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2a_se_reduce (Conv2D  (None, 1, 1, 4)              388       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2a_se_expand (Conv2D  (None, 1, 1, 96)             480       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2a_se_excite (Multip  (None, 56, 56, 96)           0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2a_project_conv (Con  (None, 56, 56, 24)           2304      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2a_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2b_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2b_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2b_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2b_dwconv (Depthwise  (None, 56, 56, 144)          1296      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2b_bn (BatchNormaliz  (None, 56, 56, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2b_activation (Activ  (None, 56, 56, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2b_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2b_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2b_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2b_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2b_se_excite (Multip  (None, 56, 56, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2b_project_conv (Con  (None, 56, 56, 24)           3456      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2b_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2b_drop (Dropout)     (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2b_add (Add)          (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2c_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2c_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2c_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2c_dwconv (Depthwise  (None, 56, 56, 144)          1296      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2c_bn (BatchNormaliz  (None, 56, 56, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2c_activation (Activ  (None, 56, 56, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2c_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2c_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2c_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2c_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2c_se_excite (Multip  (None, 56, 56, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2c_project_conv (Con  (None, 56, 56, 24)           3456      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2c_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2c_drop (Dropout)     (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2c_add (Add)          (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block3a_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3a_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3a_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3a_dwconv_pad (ZeroP  (None, 59, 59, 144)          0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block3a_dwconv (Depthwise  (None, 28, 28, 144)          3600      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3a_bn (BatchNormaliz  (None, 28, 28, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3a_activation (Activ  (None, 28, 28, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3a_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3a_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3a_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3a_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3a_se_excite (Multip  (None, 28, 28, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3a_project_conv (Con  (None, 28, 28, 40)           5760      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3a_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3b_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3b_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3b_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3b_dwconv (Depthwise  (None, 28, 28, 240)          6000      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3b_bn (BatchNormaliz  (None, 28, 28, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3b_activation (Activ  (None, 28, 28, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3b_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3b_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3b_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3b_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3b_se_excite (Multip  (None, 28, 28, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3b_project_conv (Con  (None, 28, 28, 40)           9600      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3b_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3b_drop (Dropout)     (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3b_add (Add)          (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3c_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3c_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3c_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3c_dwconv (Depthwise  (None, 28, 28, 240)          6000      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3c_bn (BatchNormaliz  (None, 28, 28, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3c_activation (Activ  (None, 28, 28, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3c_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3c_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3c_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3c_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3c_se_excite (Multip  (None, 28, 28, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3c_project_conv (Con  (None, 28, 28, 40)           9600      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3c_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3c_drop (Dropout)     (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3c_add (Add)          (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block4a_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block4a_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block4a_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block4a_dwconv_pad (ZeroP  (None, 29, 29, 240)          0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block4a_dwconv (Depthwise  (None, 14, 14, 240)          2160      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block4a_bn (BatchNormaliz  (None, 14, 14, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4a_activation (Activ  (None, 14, 14, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4a_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block4a_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block4a_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4a_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4a_se_excite (Multip  (None, 14, 14, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block4a_project_conv (Con  (None, 14, 14, 80)           19200     []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block4a_project_bn (Batch  (None, 14, 14, 80)           320       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block4b_expand_conv (Conv  (None, 14, 14, 480)          38400     []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block4b_expand_bn (BatchN  (None, 14, 14, 480)          1920      []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block4b_expand_activation  (None, 14, 14, 480)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block4b_dwconv (Depthwise  (None, 14, 14, 480)          4320      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block4b_bn (BatchNormaliz  (None, 14, 14, 480)          1920      []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4b_activation (Activ  (None, 14, 14, 480)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4b_se_squeeze (Globa  (None, 480)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block4b_se_reshape (Resha  (None, 1, 1, 480)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block4b_se_reduce (Conv2D  (None, 1, 1, 20)             9620      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4b_se_expand (Conv2D  (None, 1, 1, 480)            10080     []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# ...
# | block7b_project_conv (Con  (None, 7, 7, 320)            614400    []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block7b_project_bn (Batch  (None, 7, 7, 320)            1280      []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block7b_drop (Dropout)     (None, 7, 7, 320)            0         []                            N         |
# |                                                                                                           |
# | block7b_add (Add)          (None, 7, 7, 320)            0         []                            N         |
# |                                                                                                           |
# | top_conv (Conv2D)          (None, 7, 7, 1280)           409600    []                            N         |
# |                                                                                                           |
# | top_bn (BatchNormalizatio  (None, 7, 7, 1280)           5120      []                            N         |
# | n)                                                                                                        |
# |                                                                                                           |
# | top_activation (Activatio  (None, 7, 7, 1280)           0         []                            N         |
# | n)                                                                                                        |
# |                                                                                                           |
# | avg_pool (GlobalAveragePo  (None, 1280)                 0         []                            N         |
# | oling2D)                                                                                                  |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  shared_layers (Functional)  (None, 2048)                 2631680   ['efficientnetb1[0][0]']      Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_16 (InputLayer)      [(None, 1280)]               0         []                            Y         |
# |                                                                                                           |
# | flatten_1 (Flatten)        (None, 1280)                 0         []                            Y         |
# |                                                                                                           |
# | shared_dense_1 (Dense)     (None, 2048)                 2623488   []                            Y         |
# |                                                                                                           |
# | batch_normalization_13 (B  (None, 2048)                 8192      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | dropout_1 (Dropout)        (None, 2048)                 0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  category_output (Functiona  (None, 102)                  1103462   ['shared_layers[0][0]']       Y
#  l)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_17 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | category_dense_1 (Dense)   (None, 512)                  1049088   []                            Y         |
# |                                                                                                           |
# | batch_normalization_14 (B  (None, 512)                  2048      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | category_output_layer (De  (None, 102)                  52326     []                            Y         |
# | nse)                                                                                                      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  ingredients_output (Functi  (None, 1037)                 3027981   ['shared_layers[0][0]']       Y
#  onal)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_18 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | ingredients_dense_1 (Dens  (None, 1024)                 2098176   []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_15 (B  (None, 1024)                 4096      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_dense_2 (Dens  (None, 512)                  524800    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_16 (B  (None, 512)                  2048      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_dense_3 (Dens  (None, 256)                  131328    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_17 (B  (None, 256)                  1024      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_output_layer   (None, 1037)                 266509    []                            Y         |
# | (Dense)                                                                                                   |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  calorie_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_19 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | calorie_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_18 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | calorie_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_19 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | calorie_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  carbs_output (Functional)   (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_20 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | carbs_dense_1 (Dense)      (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_20 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | carbs_dense_2 (Dense)      (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_21 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | carbs_output_layer (Dense  (None, 1)                    33        []                            Y         |
# | )                                                                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  protein_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_21 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | protein_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_22 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_23 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  fat_output (Functional)     (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_22 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | fat_dense_1 (Dense)        (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_24 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_dense_2 (Dense)        (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_25 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_output_layer (Dense)   (None, 1)                    33        []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =============================================================================================================
# Total params: 13872894 (52.92 MB)
# Trainable params: 7288183 (27.80 MB)
# Non-trainable params: 6584711 (25.12 MB)
# _____________________________________________________________________________________________________________

# %%
flat_efficientnet.train_model(
    x=train_dataset, validation_data=validation_dataset, epochs=20, verbose=2
)

# %% [markdown]
# #### Fine tune the convolution base without weights transfer

# %%
flat_efficientnet = FlatEfficientNetB1Model(
    input_shape=(224, 224, 3),
    total_food_category=len(data_pipeline.one_hot_encoder.all_food_categories),
    total_ingredients_category=len(data_pipeline.one_hot_encoder.all_ingredients),
    model_config_name="finalCategoryNoTransferFineTuned",
)
flat_efficientnet.load_model(
    "/content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalCategoryNoTransfer/model"
)
flat_efficientnet.unfreeze_convolution_base(117)
flat_efficientnet.compile_model(keras.optimizers.Adam(learning_rate=1e-5))
flat_efficientnet.print_summary()
# Out:
# Model: "flat_efficientnetB1"
# _____________________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to                  Trainable
# =============================================================================================================
#  input_12 (InputLayer)       [(None, 224, 224, 3)]        0         []                            Y
#
#  augmentation_layers (Funct  (None, 224, 224, 3)          0         ['input_12[0][0]']            Y
#  ional)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_13 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# |                                                                                                           |
# | random_flip_1 (RandomFlip  (None, 224, 224, 3)          0         []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | random_rotation_1 (Random  (None, 224, 224, 3)          0         []                            Y         |
# | Rotation)                                                                                                 |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  preprocessing_layers (Func  (None, 224, 224, 3)          0         ['augmentation_layers[0][0]   Y
#  tional)                                                            ']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_14 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  efficientnetb1 (Functional  (None, 1280)                 6575239   ['preprocessing_layers[0][0   Y
#  )                                                                  ]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_15 (InputLayer)      [(None, 224, 224, 3)]        0         []                            N         |
# |                                                                                                           |
# | rescaling_1 (Rescaling)    (None, 224, 224, 3)          0         []                            N         |
# |                                                                                                           |
# | normalization_1 (Normaliz  (None, 224, 224, 3)          7         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | stem_conv_pad (ZeroPaddin  (None, 225, 225, 3)          0         []                            N         |
# | g2D)                                                                                                      |
# |                                                                                                           |
# | stem_conv (Conv2D)         (None, 112, 112, 32)         864       []                            N         |
# |                                                                                                           |
# | stem_bn (BatchNormalizati  (None, 112, 112, 32)         128       []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | stem_activation (Activati  (None, 112, 112, 32)         0         []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | block1a_dwconv (Depthwise  (None, 112, 112, 32)         288       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block1a_bn (BatchNormaliz  (None, 112, 112, 32)         128       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1a_activation (Activ  (None, 112, 112, 32)         0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1a_se_squeeze (Globa  (None, 32)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block1a_se_reshape (Resha  (None, 1, 1, 32)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block1a_se_reduce (Conv2D  (None, 1, 1, 8)              264       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1a_se_expand (Conv2D  (None, 1, 1, 32)             288       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1a_se_excite (Multip  (None, 112, 112, 32)         0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block1a_project_conv (Con  (None, 112, 112, 16)         512       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block1a_project_bn (Batch  (None, 112, 112, 16)         64        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block1b_dwconv (Depthwise  (None, 112, 112, 16)         144       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block1b_bn (BatchNormaliz  (None, 112, 112, 16)         64        []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1b_activation (Activ  (None, 112, 112, 16)         0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1b_se_squeeze (Globa  (None, 16)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block1b_se_reshape (Resha  (None, 1, 1, 16)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block1b_se_reduce (Conv2D  (None, 1, 1, 4)              68        []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1b_se_expand (Conv2D  (None, 1, 1, 16)             80        []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1b_se_excite (Multip  (None, 112, 112, 16)         0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block1b_project_conv (Con  (None, 112, 112, 16)         256       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block1b_project_bn (Batch  (None, 112, 112, 16)         64        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block1b_drop (Dropout)     (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | block1b_add (Add)          (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | block2a_expand_conv (Conv  (None, 112, 112, 96)         1536      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2a_expand_bn (BatchN  (None, 112, 112, 96)         384       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2a_expand_activation  (None, 112, 112, 96)         0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2a_dwconv_pad (ZeroP  (None, 113, 113, 96)         0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block2a_dwconv (Depthwise  (None, 56, 56, 96)           864       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2a_bn (BatchNormaliz  (None, 56, 56, 96)           384       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2a_activation (Activ  (None, 56, 56, 96)           0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2a_se_squeeze (Globa  (None, 96)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2a_se_reshape (Resha  (None, 1, 1, 96)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2a_se_reduce (Conv2D  (None, 1, 1, 4)              388       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2a_se_expand (Conv2D  (None, 1, 1, 96)             480       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2a_se_excite (Multip  (None, 56, 56, 96)           0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2a_project_conv (Con  (None, 56, 56, 24)           2304      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2a_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2b_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2b_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2b_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2b_dwconv (Depthwise  (None, 56, 56, 144)          1296      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2b_bn (BatchNormaliz  (None, 56, 56, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2b_activation (Activ  (None, 56, 56, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2b_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2b_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2b_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2b_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2b_se_excite (Multip  (None, 56, 56, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2b_project_conv (Con  (None, 56, 56, 24)           3456      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2b_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2b_drop (Dropout)     (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2b_add (Add)          (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2c_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2c_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2c_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2c_dwconv (Depthwise  (None, 56, 56, 144)          1296      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2c_bn (BatchNormaliz  (None, 56, 56, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2c_activation (Activ  (None, 56, 56, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2c_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2c_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2c_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2c_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2c_se_excite (Multip  (None, 56, 56, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2c_project_conv (Con  (None, 56, 56, 24)           3456      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2c_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2c_drop (Dropout)     (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2c_add (Add)          (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block3a_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3a_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3a_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3a_dwconv_pad (ZeroP  (None, 59, 59, 144)          0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block3a_dwconv (Depthwise  (None, 28, 28, 144)          3600      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3a_bn (BatchNormaliz  (None, 28, 28, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3a_activation (Activ  (None, 28, 28, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3a_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3a_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3a_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3a_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3a_se_excite (Multip  (None, 28, 28, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3a_project_conv (Con  (None, 28, 28, 40)           5760      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3a_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3b_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3b_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3b_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3b_dwconv (Depthwise  (None, 28, 28, 240)          6000      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3b_bn (BatchNormaliz  (None, 28, 28, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3b_activation (Activ  (None, 28, 28, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3b_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3b_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3b_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3b_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3b_se_excite (Multip  (None, 28, 28, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3b_project_conv (Con  (None, 28, 28, 40)           9600      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3b_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3b_drop (Dropout)     (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3b_add (Add)          (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3c_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3c_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3c_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3c_dwconv (Depthwise  (None, 28, 28, 240)          6000      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3c_bn (BatchNormaliz  (None, 28, 28, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3c_activation (Activ  (None, 28, 28, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3c_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3c_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3c_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3c_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3c_se_excite (Multip  (None, 28, 28, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3c_project_conv (Con  (None, 28, 28, 40)           9600      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3c_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3c_drop (Dropout)     (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3c_add (Add)          (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block4a_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            Y         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block4a_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            Y         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block4a_expand_activation  (None, 28, 28, 240)          0         []                            Y         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block4a_dwconv_pad (ZeroP  (None, 29, 29, 240)          0         []                            Y         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block4a_dwconv (Depthwise  (None, 14, 14, 240)          2160      []                            Y         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block4a_bn (BatchNormaliz  (None, 14, 14, 240)          960       []                            Y         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4a_activation (Activ  (None, 14, 14, 240)          0         []                            Y         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4a_se_squeeze (Globa  (None, 240)                  0         []                            Y         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block4a_se_reshape (Resha  (None, 1, 1, 240)            0         []                            Y         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block4a_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4a_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4a_se_excite (Multip  (None, 14, 14, 240)          0         []                            Y         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block4a_project_conv (Con  (None, 14, 14, 80)           19200     []                            Y         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block4a_project_bn (Batch  (None, 14, 14, 80)           320       []                            Y         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block4b_expand_conv (Conv  (None, 14, 14, 480)          38400     []                            Y         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block4b_expand_bn (BatchN  (None, 14, 14, 480)          1920      []                            Y         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block4b_expand_activation  (None, 14, 14, 480)          0         []                            Y         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block4b_dwconv (Depthwise  (None, 14, 14, 480)          4320      []                            Y         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block4b_bn (BatchNormaliz  (None, 14, 14, 480)          1920      []                            Y         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4b_activation (Activ  (None, 14, 14, 480)          0         []                            Y         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4b_se_squeeze (Globa  (None, 480)                  0         []                            Y         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block4b_se_reshape (Resha  (None, 1, 1, 480)            0         []                            Y         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block4b_se_reduce (Conv2D  (None, 1, 1, 20)             9620      []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4b_se_expand (Conv2D  (None, 1, 1, 480)            10080     []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4b_se_excite (Multip  (None, 14, 14, 480)          0         []                            Y         |
# | ly)                                                                                                       |
# ...
# | block7b_project_conv (Con  (None, 7, 7, 320)            614400    []                            Y         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block7b_project_bn (Batch  (None, 7, 7, 320)            1280      []                            Y         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block7b_drop (Dropout)     (None, 7, 7, 320)            0         []                            Y         |
# |                                                                                                           |
# | block7b_add (Add)          (None, 7, 7, 320)            0         []                            Y         |
# |                                                                                                           |
# | top_conv (Conv2D)          (None, 7, 7, 1280)           409600    []                            Y         |
# |                                                                                                           |
# | top_bn (BatchNormalizatio  (None, 7, 7, 1280)           5120      []                            Y         |
# | n)                                                                                                        |
# |                                                                                                           |
# | top_activation (Activatio  (None, 7, 7, 1280)           0         []                            Y         |
# | n)                                                                                                        |
# |                                                                                                           |
# | avg_pool (GlobalAveragePo  (None, 1280)                 0         []                            Y         |
# | oling2D)                                                                                                  |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  shared_layers (Functional)  (None, 2048)                 2631680   ['efficientnetb1[0][0]']      Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_16 (InputLayer)      [(None, 1280)]               0         []                            Y         |
# |                                                                                                           |
# | flatten_1 (Flatten)        (None, 1280)                 0         []                            Y         |
# |                                                                                                           |
# | shared_dense_1 (Dense)     (None, 2048)                 2623488   []                            Y         |
# |                                                                                                           |
# | batch_normalization_13 (B  (None, 2048)                 8192      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | dropout_1 (Dropout)        (None, 2048)                 0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  category_output (Functiona  (None, 102)                  1103462   ['shared_layers[0][0]']       Y
#  l)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_17 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | category_dense_1 (Dense)   (None, 512)                  1049088   []                            Y         |
# |                                                                                                           |
# | batch_normalization_14 (B  (None, 512)                  2048      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | category_output_layer (De  (None, 102)                  52326     []                            Y         |
# | nse)                                                                                                      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  ingredients_output (Functi  (None, 1037)                 3027981   ['shared_layers[0][0]']       Y
#  onal)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_18 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | ingredients_dense_1 (Dens  (None, 1024)                 2098176   []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_15 (B  (None, 1024)                 4096      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_dense_2 (Dens  (None, 512)                  524800    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_16 (B  (None, 512)                  2048      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_dense_3 (Dens  (None, 256)                  131328    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_17 (B  (None, 256)                  1024      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_output_layer   (None, 1037)                 266509    []                            Y         |
# | (Dense)                                                                                                   |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  calorie_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_19 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | calorie_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_18 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | calorie_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_19 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | calorie_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  carbs_output (Functional)   (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_20 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | carbs_dense_1 (Dense)      (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_20 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | carbs_dense_2 (Dense)      (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_21 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | carbs_output_layer (Dense  (None, 1)                    33        []                            Y         |
# | )                                                                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  protein_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_21 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | protein_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_22 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_23 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  fat_output (Functional)     (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_22 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | fat_dense_1 (Dense)        (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_24 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_dense_2 (Dense)        (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_25 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_output_layer (Dense)   (None, 1)                    33        []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =============================================================================================================
# Total params: 13872894 (52.92 MB)
# Trainable params: 13693025 (52.23 MB)
# Non-trainable params: 179869 (702.62 KB)
# _____________________________________________________________________________________________________________

# %%
flat_efficientnet.train_model(
    x=train_dataset,
    validation_data=validation_dataset,
    epochs=10,
    verbose=2,
)
# Out:
# Epoch 1/10
# 334/334 - 956s - loss: 3.7696 - category_output_loss: 3.0041 - ingredients_output_loss: 0.0267 - calorie_output_loss: 0.5799 - carbs_output_loss: 0.0769 - protein_output_loss: 0.0232 - fat_output_loss: 0.0588 - category_output_acc: 0.3558 - category_output_precision: 0.5328 - category_output_recall: 0.2743 - ingredients_output_precision: 0.6276 - ingredients_output_recall: 0.3791 - calorie_output_MAE: 0.5799 - carbs_output_MAE: 0.0769 - protein_output_MAE: 0.0232 - fat_output_MAE: 0.0588 - val_loss: 2.9596 - val_category_output_loss: 2.2751 - val_ingredients_output_loss: 0.0224 - val_calorie_output_loss: 0.5227 - val_carbs_output_loss: 0.0660 - val_protein_output_loss: 0.0206 - val_fat_output_loss: 0.0529 - val_category_output_acc: 0.5023 - val_category_output_precision: 0.6452 - val_category_output_recall: 0.4410 - val_ingredients_output_precision: 0.7234 - val_ingredients_output_recall: 0.4859 - val_calorie_output_MAE: 0.5227 - val_carbs_output_MAE: 0.0660 - val_protein_output_MAE: 0.0206 - val_fat_output_MAE: 0.0529 - lr: 1.0000e-05 - 956s/epoch - 3s/step
# Epoch 2/10
# 334/334 - 908s - loss: 2.8282 - category_output_loss: 2.1322 - ingredients_output_loss: 0.0225 - calorie_output_loss: 0.5292 - carbs_output_loss: 0.0688 - protein_output_loss: 0.0212 - fat_output_loss: 0.0542 - category_output_acc: 0.4878 - category_output_precision: 0.6538 - category_output_recall: 0.4017 - ingredients_output_precision: 0.7146 - ingredients_output_recall: 0.4450 - calorie_output_MAE: 0.5292 - carbs_output_MAE: 0.0688 - protein_output_MAE: 0.0212 - fat_output_MAE: 0.0542 - val_loss: 2.6493 - val_category_output_loss: 1.9908 - val_ingredients_output_loss: 0.0207 - val_calorie_output_loss: 0.5038 - val_carbs_output_loss: 0.0630 - val_protein_output_loss: 0.0198 - val_fat_output_loss: 0.0512 - val_category_output_acc: 0.5466 - val_category_output_precision: 0.6870 - val_category_output_recall: 0.4850 - val_ingredients_output_precision: 0.7599 - val_ingredients_output_recall: 0.5054 - val_calorie_output_MAE: 0.5038 - val_carbs_output_MAE: 0.0630 - val_protein_output_MAE: 0.0198 - val_fat_output_MAE: 0.0512 - lr: 1.0000e-05 - 908s/epoch - 3s/step
# %% [markdown]
# ### MobileNetv3

# %%
class FlatMobileNetv3Model(FlatModel):
    def __init__(
        self,
        input_shape,
        total_food_category,
        total_ingredients_category,
        model_config_name,
    ):
        super().__init__(
            input_shape,
            total_food_category,
            total_ingredients_category,
            "flat_mobilenetv3",
            model_config_name,
        )

    def get_preprocess_layers(self, input_tensor):
        input_layer = keras.layers.Input(shape=input_tensor.shape[1:])
        output_layer = keras.applications.mobilenet_v3.preprocess_input(input_layer)
        return keras.Model(
            inputs=input_layer, outputs=output_layer, name="preprocessing_layers"
        )

    def get_convolution_block(self):
        mobilenet_v3_convolution_layers = keras.applications.MobileNetV3Large(
            input_shape=self.input_shape,
            include_top=False,
            weights="imagenet",
            pooling="avg",
        )
        mobilenet_v3_convolution_layers.trainable = False
        return mobilenet_v3_convolution_layers

# %% [markdown]
# #### Train on main dataset (recipes5k + food101 + nutrition5k)

# %%
flat_mobilenetv3 = FlatMobileNetv3Model(
    input_shape=(224, 224, 3),
    total_food_category=len(data_pipeline.one_hot_encoder.all_food_categories),
    total_ingredients_category=len(data_pipeline.one_hot_encoder.all_ingredients),
    model_config_name="1-2048-(1-512)-[(2-64-32)-(2-64-32)-(2-64-32)-(2-64-32)]-(3-1024-512-256)-B256",
)

flat_mobilenetv3.build(
    shared_units=[2048],
    independent_category_units=[512],
    independent_ingredients_units=[1024, 512, 256],
    independent_protein_units=[64, 32],
    independent_fat_units=[64, 32],
    independent_carbs_units=[64, 32],
    independent_calorie_units=[64, 32],
)
flat_mobilenetv3.compile_model(keras.optimizers.Adam())
flat_mobilenetv3.print_summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 0s 0us/step
# Model: "flat_mobilenetv3"
# _____________________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to                  Trainable
# =============================================================================================================
#  input_23 (InputLayer)       [(None, 224, 224, 3)]        0         []                            Y
#
#  augmentation_layers (Funct  (None, 224, 224, 3)          0         ['input_23[0][0]']            Y
#  ional)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_24 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# |                                                                                                           |
# | random_flip_2 (RandomFlip  (None, 224, 224, 3)          0         []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | random_rotation_2 (Random  (None, 224, 224, 3)          0         []                            Y         |
# | Rotation)                                                                                                 |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  preprocessing_layers (Func  (None, 224, 224, 3)          0         ['augmentation_layers[0][0]   Y
#  tional)                                                            ']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_25 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  MobilenetV3large (Function  (None, 960)                  2996352   ['preprocessing_layers[0][0   N
#  al)                                                                ]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_26 (InputLayer)      [(None, 224, 224, 3)]        0         []                            N         |
# |                                                                                                           |
# | rescaling_4 (Rescaling)    (None, 224, 224, 3)          0         []                            N         |
# |                                                                                                           |
# | Conv (Conv2D)              (None, 112, 112, 16)         432       []                            N         |
# |                                                                                                           |
# | Conv/BatchNorm (BatchNorm  (None, 112, 112, 16)         64        []                            N         |
# | alization)                                                                                                |
# |                                                                                                           |
# | tf.__operators__.add (TFO  (None, 112, 112, 16)         0         []                            N         |
# | pLambda)                                                                                                  |
# |                                                                                                           |
# | re_lu (ReLU)               (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply (TFOpLam  (None, 112, 112, 16)         0         []                            N         |
# | bda)                                                                                                      |
# |                                                                                                           |
# | multiply (Multiply)        (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | expanded_conv/depthwise (  (None, 112, 112, 16)         144       []                            N         |
# | DepthwiseConv2D)                                                                                          |
# |                                                                                                           |
# | expanded_conv/depthwise/B  (None, 112, 112, 16)         64        []                            N         |
# | atchNorm (BatchNormalizat                                                                                 |
# | ion)                                                                                                      |
# |                                                                                                           |
# | re_lu_1 (ReLU)             (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | expanded_conv/project (Co  (None, 112, 112, 16)         256       []                            N         |
# | nv2D)                                                                                                     |
# |                                                                                                           |
# | expanded_conv/project/Bat  (None, 112, 112, 16)         64        []                            N         |
# | chNorm (BatchNormalizatio                                                                                 |
# | n)                                                                                                        |
# |                                                                                                           |
# | expanded_conv/Add (Add)    (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | expanded_conv_1/expand (C  (None, 112, 112, 64)         1024      []                            N         |
# | onv2D)                                                                                                    |
# |                                                                                                           |
# | expanded_conv_1/expand/Ba  (None, 112, 112, 64)         256       []                            N         |
# | tchNorm (BatchNormalizati                                                                                 |
# | on)                                                                                                       |
# |                                                                                                           |
# | re_lu_2 (ReLU)             (None, 112, 112, 64)         0         []                            N         |
# |                                                                                                           |
# | expanded_conv_1/depthwise  (None, 113, 113, 64)         0         []                            N         |
# | /pad (ZeroPadding2D)                                                                                      |
# |                                                                                                           |
# | expanded_conv_1/depthwise  (None, 56, 56, 64)           576       []                            N         |
# |  (DepthwiseConv2D)                                                                                        |
# |                                                                                                           |
# | expanded_conv_1/depthwise  (None, 56, 56, 64)           256       []                            N         |
# | /BatchNorm (BatchNormaliz                                                                                 |
# | ation)                                                                                                    |
# |                                                                                                           |
# | re_lu_3 (ReLU)             (None, 56, 56, 64)           0         []                            N         |
# |                                                                                                           |
# | expanded_conv_1/project (  (None, 56, 56, 24)           1536      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | expanded_conv_1/project/B  (None, 56, 56, 24)           96        []                            N         |
# | atchNorm (BatchNormalizat                                                                                 |
# | ion)                                                                                                      |
# |                                                                                                           |
# | expanded_conv_2/expand (C  (None, 56, 56, 72)           1728      []                            N         |
# | onv2D)                                                                                                    |
# |                                                                                                           |
# | expanded_conv_2/expand/Ba  (None, 56, 56, 72)           288       []                            N         |
# | tchNorm (BatchNormalizati                                                                                 |
# | on)                                                                                                       |
# |                                                                                                           |
# | re_lu_4 (ReLU)             (None, 56, 56, 72)           0         []                            N         |
# |                                                                                                           |
# | expanded_conv_2/depthwise  (None, 56, 56, 72)           648       []                            N         |
# |  (DepthwiseConv2D)                                                                                        |
# |                                                                                                           |
# | expanded_conv_2/depthwise  (None, 56, 56, 72)           288       []                            N         |
# | /BatchNorm (BatchNormaliz                                                                                 |
# | ation)                                                                                                    |
# |                                                                                                           |
# | re_lu_5 (ReLU)             (None, 56, 56, 72)           0         []                            N         |
# |                                                                                                           |
# | expanded_conv_2/project (  (None, 56, 56, 24)           1728      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | expanded_conv_2/project/B  (None, 56, 56, 24)           96        []                            N         |
# | atchNorm (BatchNormalizat                                                                                 |
# | ion)                                                                                                      |
# |                                                                                                           |
# | expanded_conv_2/Add (Add)  (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | expanded_conv_3/expand (C  (None, 56, 56, 72)           1728      []                            N         |
# | onv2D)                                                                                                    |
# |                                                                                                           |
# | expanded_conv_3/expand/Ba  (None, 56, 56, 72)           288       []                            N         |
# | tchNorm (BatchNormalizati                                                                                 |
# | on)                                                                                                       |
# |                                                                                                           |
# | re_lu_6 (ReLU)             (None, 56, 56, 72)           0         []                            N         |
# |                                                                                                           |
# | expanded_conv_3/depthwise  (None, 59, 59, 72)           0         []                            N         |
# | /pad (ZeroPadding2D)                                                                                      |
# |                                                                                                           |
# | expanded_conv_3/depthwise  (None, 28, 28, 72)           1800      []                            N         |
# |  (DepthwiseConv2D)                                                                                        |
# |                                                                                                           |
# | expanded_conv_3/depthwise  (None, 28, 28, 72)           288       []                            N         |
# | /BatchNorm (BatchNormaliz                                                                                 |
# | ation)                                                                                                    |
# |                                                                                                           |
# | re_lu_7 (ReLU)             (None, 28, 28, 72)           0         []                            N         |
# |                                                                                                           |
# | expanded_conv_3/squeeze_e  (None, 1, 1, 72)             0         []                            N         |
# | xcite/AvgPool (GlobalAver                                                                                 |
# | agePooling2D)                                                                                             |
# |                                                                                                           |
# | expanded_conv_3/squeeze_e  (None, 1, 1, 24)             1752      []                            N         |
# | xcite/Conv (Conv2D)                                                                                       |
# |                                                                                                           |
# | expanded_conv_3/squeeze_e  (None, 1, 1, 24)             0         []                            N         |
# | xcite/Relu (ReLU)                                                                                         |
# |                                                                                                           |
# | expanded_conv_3/squeeze_e  (None, 1, 1, 72)             1800      []                            N         |
# | xcite/Conv_1 (Conv2D)                                                                                     |
# |                                                                                                           |
# | tf.__operators__.add_1 (T  (None, 1, 1, 72)             0         []                            N         |
# | FOpLambda)                                                                                                |
# |                                                                                                           |
# | re_lu_8 (ReLU)             (None, 1, 1, 72)             0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply_1 (TFOpL  (None, 1, 1, 72)             0         []                            N         |
# | ambda)                                                                                                    |
# |                                                                                                           |
# | expanded_conv_3/squeeze_e  (None, 28, 28, 72)           0         []                            N         |
# | xcite/Mul (Multiply)                                                                                      |
# |                                                                                                           |
# | expanded_conv_3/project (  (None, 28, 28, 40)           2880      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | expanded_conv_3/project/B  (None, 28, 28, 40)           160       []                            N         |
# | atchNorm (BatchNormalizat                                                                                 |
# | ion)                                                                                                      |
# |                                                                                                           |
# | expanded_conv_4/expand (C  (None, 28, 28, 120)          4800      []                            N         |
# | onv2D)                                                                                                    |
# |                                                                                                           |
# | expanded_conv_4/expand/Ba  (None, 28, 28, 120)          480       []                            N         |
# | tchNorm (BatchNormalizati                                                                                 |
# | on)                                                                                                       |
# |                                                                                                           |
# | re_lu_9 (ReLU)             (None, 28, 28, 120)          0         []                            N         |
# |                                                                                                           |
# | expanded_conv_4/depthwise  (None, 28, 28, 120)          3000      []                            N         |
# |  (DepthwiseConv2D)                                                                                        |
# |                                                                                                           |
# | expanded_conv_4/depthwise  (None, 28, 28, 120)          480       []                            N         |
# | /BatchNorm (BatchNormaliz                                                                                 |
# | ation)                                                                                                    |
# |                                                                                                           |
# | re_lu_10 (ReLU)            (None, 28, 28, 120)          0         []                            N         |
# |                                                                                                           |
# | expanded_conv_4/squeeze_e  (None, 1, 1, 120)            0         []                            N         |
# | xcite/AvgPool (GlobalAver                                                                                 |
# | agePooling2D)                                                                                             |
# |                                                                                                           |
# | expanded_conv_4/squeeze_e  (None, 1, 1, 32)             3872      []                            N         |
# | xcite/Conv (Conv2D)                                                                                       |
# |                                                                                                           |
# | expanded_conv_4/squeeze_e  (None, 1, 1, 32)             0         []                            N         |
# | xcite/Relu (ReLU)                                                                                         |
# |                                                                                                           |
# | expanded_conv_4/squeeze_e  (None, 1, 1, 120)            3960      []                            N         |
# | xcite/Conv_1 (Conv2D)                                                                                     |
# |                                                                                                           |
# | tf.__operators__.add_2 (T  (None, 1, 1, 120)            0         []                            N         |
# | FOpLambda)                                                                                                |
# |                                                                                                           |
# | re_lu_11 (ReLU)            (None, 1, 1, 120)            0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply_2 (TFOpL  (None, 1, 1, 120)            0         []                            N         |
# | ambda)                                                                                                    |
# |                                                                                                           |
# | expanded_conv_4/squeeze_e  (None, 28, 28, 120)          0         []                            N         |
# | xcite/Mul (Multiply)                                                                                      |
# |                                                                                                           |
# | expanded_conv_4/project (  (None, 28, 28, 40)           4800      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | expanded_conv_4/project/B  (None, 28, 28, 40)           160       []                            N         |
# | atchNorm (BatchNormalizat                                                                                 |
# | ion)                                                                                                      |
# |                                                                                                           |
# | expanded_conv_4/Add (Add)  (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | expanded_conv_5/expand (C  (None, 28, 28, 120)          4800      []                            N         |
# | onv2D)                                                                                                    |
# |                                                                                                           |
# | expanded_conv_5/expand/Ba  (None, 28, 28, 120)          480       []                            N         |
# | tchNorm (BatchNormalizati                                                                                 |
# | on)                                                                                                       |
# |                                                                                                           |
# | re_lu_12 (ReLU)            (None, 28, 28, 120)          0         []                            N         |
# |                                                                                                           |
# | expanded_conv_5/depthwise  (None, 28, 28, 120)          3000      []                            N         |
# |  (DepthwiseConv2D)                                                                                        |
# |                                                                                                           |
# | expanded_conv_5/depthwise  (None, 28, 28, 120)          480       []                            N         |
# | /BatchNorm (BatchNormaliz                                                                                 |
# | ation)                                                                                                    |
# |                                                                                                           |
# | re_lu_13 (ReLU)            (None, 28, 28, 120)          0         []                            N         |
# |                                                                                                           |
# | expanded_conv_5/squeeze_e  (None, 1, 1, 120)            0         []                            N         |
# | xcite/AvgPool (GlobalAver                                                                                 |
# | agePooling2D)                                                                                             |
# |                                                                                                           |
# | expanded_conv_5/squeeze_e  (None, 1, 1, 32)             3872      []                            N         |
# | xcite/Conv (Conv2D)                                                                                       |
# |                                                                                                           |
# | expanded_conv_5/squeeze_e  (None, 1, 1, 32)             0         []                            N         |
# | xcite/Relu (ReLU)                                                                                         |
# |                                                                                                           |
# | expanded_conv_5/squeeze_e  (None, 1, 1, 120)            3960      []                            N         |
# | xcite/Conv_1 (Conv2D)                                                                                     |
# |                                                                                                           |
# | tf.__operators__.add_3 (T  (None, 1, 1, 120)            0         []                            N         |
# | FOpLambda)                                                                                                |
# |                                                                                                           |
# | re_lu_14 (ReLU)            (None, 1, 1, 120)            0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply_3 (TFOpL  (None, 1, 1, 120)            0         []                            N         |
# | ambda)                                                                                                    |
# |                                                                                                           |
# | expanded_conv_5/squeeze_e  (None, 28, 28, 120)          0         []                            N         |
# | xcite/Mul (Multiply)                                                                                      |
# |                                                                                                           |
# | expanded_conv_5/project (  (None, 28, 28, 40)           4800      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | expanded_conv_5/project/B  (None, 28, 28, 40)           160       []                            N         |
# | atchNorm (BatchNormalizat                                                                                 |
# | ion)                                                                                                      |
# |                                                                                                           |
# | expanded_conv_5/Add (Add)  (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | expanded_conv_6/expand (C  (None, 28, 28, 240)          9600      []                            N         |
# | onv2D)                                                                                                    |
# |                                                                                                           |
# | expanded_conv_6/expand/Ba  (None, 28, 28, 240)          960       []                            N         |
# | tchNorm (BatchNormalizati                                                                                 |
# | on)                                                                                                       |
# |                                                                                                           |
# | tf.__operators__.add_4 (T  (None, 28, 28, 240)          0         []                            N         |
# | FOpLambda)                                                                                                |
# |                                                                                                           |
# | re_lu_15 (ReLU)            (None, 28, 28, 240)          0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply_4 (TFOpL  (None, 28, 28, 240)          0         []                            N         |
# | ambda)                                                                                                    |
# |                                                                                                           |
# | multiply_1 (Multiply)      (None, 28, 28, 240)          0         []                            N         |
# |                                                                                                           |
# | expanded_conv_6/depthwise  (None, 29, 29, 240)          0         []                            N         |
# | /pad (ZeroPadding2D)                                                                                      |
# |                                                                                                           |
# | expanded_conv_6/depthwise  (None, 14, 14, 240)          2160      []                            N         |
# |  (DepthwiseConv2D)                                                                                        |
# |                                                                                                           |
# | expanded_conv_6/depthwise  (None, 14, 14, 240)          960       []                            N         |
# | /BatchNorm (BatchNormaliz                                                                                 |
# | ation)                                                                                                    |
# |                                                                                                           |
# | tf.__operators__.add_5 (T  (None, 14, 14, 240)          0         []                            N         |
# | FOpLambda)                                                                                                |
# |                                                                                                           |
# | re_lu_16 (ReLU)            (None, 14, 14, 240)          0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply_5 (TFOpL  (None, 14, 14, 240)          0         []                            N         |
# | ambda)                                                                                                    |
# |                                                                                                           |
# | multiply_2 (Multiply)      (None, 14, 14, 240)          0         []                            N         |
# |                                                                                                           |
# | expanded_conv_6/project (  (None, 14, 14, 80)           19200     []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | expanded_conv_6/project/B  (None, 14, 14, 80)           320       []                            N         |
# | atchNorm (BatchNormalizat                                                                                 |
# | ion)                                                                                                      |
# |                                                                                                           |
# | expanded_conv_7/expand (C  (None, 14, 14, 200)          16000     []                            N         |
# | onv2D)                                                                                                    |
# |                                                                                                           |
# | expanded_conv_7/expand/Ba  (None, 14, 14, 200)          800       []                            N         |
# | tchNorm (BatchNormalizati                                                                                 |
# | on)                                                                                                       |
# |                                                                                                           |
# | tf.__operators__.add_6 (T  (None, 14, 14, 200)          0         []                            N         |
# | FOpLambda)                                                                                                |
# |                                                                                                           |
# | re_lu_17 (ReLU)            (None, 14, 14, 200)          0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply_6 (TFOpL  (None, 14, 14, 200)          0         []                            N         |
# | ambda)                                                                                                    |
# |                                                                                                           |
# | multiply_3 (Multiply)      (None, 14, 14, 200)          0         []                            N         |
# |                                                                                                           |
# | expanded_conv_7/depthwise  (None, 14, 14, 200)          1800      []                            N         |
# |  (DepthwiseConv2D)                                                                                        |
# |                                                                                                           |
# | expanded_conv_7/depthwise  (None, 14, 14, 200)          800       []                            N         |
# | /BatchNorm (BatchNormaliz                                                                                 |
# | ation)                                                                                                    |
# |                                                                                                           |
# | tf.__operators__.add_7 (T  (None, 14, 14, 200)          0         []                            N         |
# | FOpLambda)                                                                                                |
# |                                                                                                           |
# | re_lu_18 (ReLU)            (None, 14, 14, 200)          0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply_7 (TFOpL  (None, 14, 14, 200)          0         []                            N         |
# | ambda)                                                                                                    |
# |                                                                                                           |
# | multiply_4 (Multiply)      (None, 14, 14, 200)          0         []                            N         |
# |                                                                                                           |
# | expanded_conv_7/project (  (None, 14, 14, 80)           16000     []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | expanded_conv_7/project/B  (None, 14, 14, 80)           320       []                            N         |
# | atchNorm (BatchNormalizat                                                                                 |
# | ion)                                                                                                      |
# |                                                                                                           |
# | expanded_conv_7/Add (Add)  (None, 14, 14, 80)           0         []                            N         |
# |                                                                                                           |
# | expanded_conv_8/expand (C  (None, 14, 14, 184)          14720     []                            N         |
# | onv2D)                                                                                                    |
# |                                                                                                           |
# | expanded_conv_8/expand/Ba  (None, 14, 14, 184)          736       []                            N         |
# | tchNorm (BatchNormalizati                                                                                 |
# | on)                                                                                                       |
# |                                                                                                           |
# | tf.__operators__.add_8 (T  (None, 14, 14, 184)          0         []                            N         |
# | FOpLambda)                                                                                                |
# |                                                                                                           |
# | re_lu_19 (ReLU)            (None, 14, 14, 184)          0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply_8 (TFOpL  (None, 14, 14, 184)          0         []                            N         |
# | ambda)                                                                                                    |
# |                                                                                                           |
# | multiply_5 (Multiply)      (None, 14, 14, 184)          0         []                            N         |
# |                                                                                                           |
# | expanded_conv_8/depthwise  (None, 14, 14, 184)          1656      []                            N         |
# |  (DepthwiseConv2D)                                                                                        |
# |                                                                                                           |
# | expanded_conv_8/depthwise  (None, 14, 14, 184)          736       []                            N         |
# | /BatchNorm (BatchNormaliz                                                                                 |
# | ation)                                                                                                    |
# |                                                                                                           |
# | tf.__operators__.add_9 (T  (None, 14, 14, 184)          0         []                            N         |
# | FOpLambda)                                                                                                |
# |                                                                                                           |
# | re_lu_20 (ReLU)            (None, 14, 14, 184)          0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply_9 (TFOpL  (None, 14, 14, 184)          0         []                            N         |
# | ambda)                                                                                                    |
# |                                                                                                           |
# | multiply_6 (Multiply)      (None, 14, 14, 184)          0         []                            N         |
# |                                                                                                           |
# | expanded_conv_8/project (  (None, 14, 14, 80)           14720     []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | expanded_conv_8/project/B  (None, 14, 14, 80)           320       []                            N         |
# | atchNorm (BatchNormalizat                                                                                 |
# | ion)                                                                                                      |
# |                                                                                                           |
# | expanded_conv_8/Add (Add)  (None, 14, 14, 80)           0         []                            N         |
# |                                                                                                           |
# | expanded_conv_9/expand (C  (None, 14, 14, 184)          14720     []                            N         |
# | onv2D)                                                                                                    |
# |                                                                                                           |
# | expanded_conv_9/expand/Ba  (None, 14, 14, 184)          736       []                            N         |
# | tchNorm (BatchNormalizati                                                                                 |
# | on)                                                                                                       |
# |                                                                                                           |
# | tf.__operators__.add_10 (  (None, 14, 14, 184)          0         []                            N         |
# | TFOpLambda)                                                                                               |
# |                                                                                                           |
# | re_lu_21 (ReLU)            (None, 14, 14, 184)          0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply_10 (TFOp  (None, 14, 14, 184)          0         []                            N         |
# | Lambda)                                                                                                   |
# |                                                                                                           |
# | multiply_7 (Multiply)      (None, 14, 14, 184)          0         []                            N         |
# |                                                                                                           |
# | expanded_conv_9/depthwise  (None, 14, 14, 184)          1656      []                            N         |
# |  (DepthwiseConv2D)                                                                                        |
# |                                                                                                           |
# | expanded_conv_9/depthwise  (None, 14, 14, 184)          736       []                            N         |
# | /BatchNorm (BatchNormaliz                                                                                 |
# | ation)                                                                                                    |
# |                                                                                                           |
# | tf.__operators__.add_11 (  (None, 14, 14, 184)          0         []                            N         |
# | TFOpLambda)                                                                                               |
# |                                                                                                           |
# | re_lu_22 (ReLU)            (None, 14, 14, 184)          0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply_11 (TFOp  (None, 14, 14, 184)          0         []                            N         |
# | Lambda)                                                                                                   |
# |                                                                                                           |
# | multiply_8 (Multiply)      (None, 14, 14, 184)          0         []                            N         |
# |                                                                                                           |
# ...
# | expanded_conv_14/Add (Add  (None, 7, 7, 160)            0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | Conv_1 (Conv2D)            (None, 7, 7, 960)            153600    []                            N         |
# |                                                                                                           |
# | Conv_1/BatchNorm (BatchNo  (None, 7, 7, 960)            3840      []                            N         |
# | rmalization)                                                                                              |
# |                                                                                                           |
# | tf.__operators__.add_27 (  (None, 7, 7, 960)            0         []                            N         |
# | TFOpLambda)                                                                                               |
# |                                                                                                           |
# | re_lu_38 (ReLU)            (None, 7, 7, 960)            0         []                            N         |
# |                                                                                                           |
# | tf.math.multiply_27 (TFOp  (None, 7, 7, 960)            0         []                            N         |
# | Lambda)                                                                                                   |
# |                                                                                                           |
# | multiply_19 (Multiply)     (None, 7, 7, 960)            0         []                            N         |
# |                                                                                                           |
# | avg_pool (GlobalAveragePo  (None, 960)                  0         []                            N         |
# | oling2D)                                                                                                  |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  shared_layers (Functional)  (None, 2048)                 1976320   ['MobilenetV3large[0][0]']    Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_27 (InputLayer)      [(None, 960)]                0         []                            Y         |
# |                                                                                                           |
# | flatten_2 (Flatten)        (None, 960)                  0         []                            Y         |
# |                                                                                                           |
# | shared_dense_1 (Dense)     (None, 2048)                 1968128   []                            Y         |
# |                                                                                                           |
# | batch_normalization_26 (B  (None, 2048)                 8192      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | dropout_2 (Dropout)        (None, 2048)                 0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  category_output (Functiona  (None, 102)                  1103462   ['shared_layers[0][0]']       Y
#  l)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_28 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | category_dense_1 (Dense)   (None, 512)                  1049088   []                            Y         |
# |                                                                                                           |
# | batch_normalization_27 (B  (None, 512)                  2048      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | category_output_layer (De  (None, 102)                  52326     []                            Y         |
# | nse)                                                                                                      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  ingredients_output (Functi  (None, 1037)                 3027981   ['shared_layers[0][0]']       Y
#  onal)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_29 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | ingredients_dense_1 (Dens  (None, 1024)                 2098176   []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_28 (B  (None, 1024)                 4096      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_dense_2 (Dens  (None, 512)                  524800    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_29 (B  (None, 512)                  2048      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_dense_3 (Dens  (None, 256)                  131328    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_30 (B  (None, 256)                  1024      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_output_layer   (None, 1037)                 266509    []                            Y         |
# | (Dense)                                                                                                   |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  calorie_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_30 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | calorie_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_31 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | calorie_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_32 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | calorie_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  carbs_output (Functional)   (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_31 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | carbs_dense_1 (Dense)      (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_33 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | carbs_dense_2 (Dense)      (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_34 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | carbs_output_layer (Dense  (None, 1)                    33        []                            Y         |
# | )                                                                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  protein_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_32 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | protein_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_35 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_36 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  fat_output (Functional)     (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_33 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | fat_dense_1 (Dense)        (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_37 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_dense_2 (Dense)        (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_38 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_output_layer (Dense)   (None, 1)                    33        []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =============================================================================================================
# Total params: 9638647 (36.77 MB)
# Trainable params: 6632823 (25.30 MB)
# Non-trainable params: 3005824 (11.47 MB)
# _____________________________________________________________________________________________________________

# %%
flat_mobilenetv3.train_model(
    x=no_category_train, validation_data=no_category_val, epochs=2, verbose=1
)
# Out:
# Epoch 1/2
# 850/850 [==============================] - 1435s 2s/step - loss: 1.0402 - category_output_loss: 0.2438 - ingredients_output_loss: 0.0648 - calorie_output_loss: 0.4851 - carbs_output_loss: 0.0824 - protein_output_loss: 0.0762 - fat_output_loss: 0.0879 - category_output_acc: 0.9702 - category_output_precision: 1.0000 - category_output_recall: 0.9282 - ingredients_output_precision: 0.0862 - ingredients_output_recall: 0.3566 - calorie_output_MAE: 0.4851 - carbs_output_MAE: 0.0824 - protein_output_MAE: 0.0762 - fat_output_MAE: 0.0879 - val_loss: 0.4663 - val_category_output_loss: 8.9781e-04 - val_ingredients_output_loss: 0.0072 - val_calorie_output_loss: 0.3377 - val_carbs_output_loss: 0.0433 - val_protein_output_loss: 0.0331 - val_fat_output_loss: 0.0442 - val_category_output_acc: 1.0000 - val_category_output_precision: 1.0000 - val_category_output_recall: 1.0000 - val_ingredients_output_precision: 0.8304 - val_ingredients_output_recall: 0.5059 - val_calorie_output_MAE: 0.3377 - val_carbs_output_MAE: 0.0433 - val_protein_output_MAE: 0.0331 - val_fat_output_MAE: 0.0442 - lr: 0.0010
# Epoch 2/2
# 850/850 [==============================] - 1426s 2s/step - loss: 0.4289 - category_output_loss: 4.3162e-04 - ingredients_output_loss: 0.0061 - calorie_output_loss: 0.3118 - carbs_output_loss: 0.0421 - protein_output_loss: 0.0312 - fat_output_loss: 0.0372 - category_output_acc: 1.0000 - category_output_precision: 1.0000 - category_output_recall: 1.0000 - ingredients_output_precision: 0.8391 - ingredients_output_recall: 0.5685 - calorie_output_MAE: 0.3118 - carbs_output_MAE: 0.0421 - protein_output_MAE: 0.0312 - fat_output_MAE: 0.0372 - val_loss: 0.3933 - val_category_output_loss: 2.2205e-04 - val_ingredients_output_loss: 0.0056 - val_calorie_output_loss: 0.2809 - val_carbs_output_loss: 0.0367 - val_protein_output_loss: 0.0369 - val_fat_output_loss: 0.0329 - val_category_output_acc: 1.0000 - val_category_output_precision: 1.0000 - val_category_output_recall: 1.0000 - val_ingredients_output_precision: 0.7806 - val_ingredients_output_recall: 0.6540 - val_calorie_output_MAE: 0.2809 - val_carbs_output_MAE: 0.0367 - val_protein_output_MAE: 0.0369 - val_fat_output_MAE: 0.0329 - lr: 0.0010

# %% [markdown]
# ### NASNet Mobile

# %%
class FlatNASNetModel(FlatModel):
    def __init__(
        self,
        input_shape,
        total_food_category,
        total_ingredients_category,
        model_config_name,
    ):
        super().__init__(
            input_shape,
            total_food_category,
            total_ingredients_category,
            "flat_nasnet",
            model_config_name,
        )

    def get_preprocess_layers(self, input_tensor):
        input_layer = keras.layers.Input(shape=input_tensor.shape[1:])
        output_layer = keras.applications.nasnet.preprocess_input(input_layer)
        return keras.Model(
            inputs=input_layer, outputs=output_layer, name="preprocessing_layers"
        )

    def get_convolution_block(self):
        nasnet_convolution_layers = keras.applications.nasnet.NASNetMobile(
            input_shape=self.input_shape,
            include_top=False,
            weights="imagenet",
            pooling="avg",
        )
        nasnet_convolution_layers.trainable = False
        return nasnet_convolution_layers

# %% [markdown]
# #### Train on main dataset (recipes5k + food101 + nutrition5k)

# %%
flat_nasnet = FlatNASNetModel(
    input_shape=(224, 224, 3),
    total_food_category=len(data_pipeline.one_hot_encoder.all_food_categories),
    total_ingredients_category=len(data_pipeline.one_hot_encoder.all_ingredients),
    model_config_name="1-2048-(1-512)-[(2-64-32)-(2-64-32)-(2-64-32)-(2-64-32)]-(3-1024-512-256)-B256",
)

flat_nasnet.build(
    shared_units=[2048],
    independent_category_units=[512],
    independent_ingredients_units=[1024, 512, 256],
    independent_protein_units=[64, 32],
    independent_fat_units=[64, 32],
    independent_carbs_units=[64, 32],
    independent_calorie_units=[64, 32],
)
flat_nasnet.compile_model(keras.optimizers.Adam())

flat_nasnet.print_summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 [==============================] - 0s 0us/step
# Model: "flat_nasnet"
# _____________________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to                  Trainable
# =============================================================================================================
#  input_34 (InputLayer)       [(None, 224, 224, 3)]        0         []                            Y
#
#  augmentation_layers (Funct  (None, 224, 224, 3)          0         ['input_34[0][0]']            Y
#  ional)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_35 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# |                                                                                                           |
# | random_flip_3 (RandomFlip  (None, 224, 224, 3)          0         []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | random_rotation_3 (Random  (None, 224, 224, 3)          0         []                            Y         |
# | Rotation)                                                                                                 |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  preprocessing_layers (Func  (None, 224, 224, 3)          0         ['augmentation_layers[0][0]   Y
#  tional)                                                            ']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_36 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# |                                                                                                           |
# | tf.math.truediv (TFOpLamb  (None, 224, 224, 3)          0         []                            Y         |
# | da)                                                                                                       |
# |                                                                                                           |
# | tf.math.subtract (TFOpLam  (None, 224, 224, 3)          0         []                            Y         |
# | bda)                                                                                                      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  NASNet (Functional)         (None, 1056)                 4269716   ['preprocessing_layers[0][0   N
#                                                                     ]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_37 (InputLayer)      [(None, 224, 224, 3)]        0         []                            N         |
# |                                                                                                           |
# | stem_conv1 (Conv2D)        (None, 111, 111, 32)         864       []                            N         |
# |                                                                                                           |
# | stem_bn1 (BatchNormalizat  (None, 111, 111, 32)         128       []                            N         |
# | ion)                                                                                                      |
# |                                                                                                           |
# | activation (Activation)    (None, 111, 111, 32)         0         []                            N         |
# |                                                                                                           |
# | reduction_conv_1_stem_1 (  (None, 111, 111, 11)         352       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | reduction_bn_1_stem_1 (Ba  (None, 111, 111, 11)         44        []                            N         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | activation_1 (Activation)  (None, 111, 111, 11)         0         []                            N         |
# |                                                                                                           |
# | activation_3 (Activation)  (None, 111, 111, 32)         0         []                            N         |
# |                                                                                                           |
# | separable_conv_1_pad_redu  (None, 115, 115, 11)         0         []                            N         |
# | ction_left1_stem_1 (ZeroP                                                                                 |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | separable_conv_1_pad_redu  (None, 117, 117, 32)         0         []                            N         |
# | ction_right1_stem_1 (Zero                                                                                 |
# | Padding2D)                                                                                                |
# |                                                                                                           |
# | separable_conv_1_reductio  (None, 56, 56, 11)           396       []                            N         |
# | n_left1_stem_1 (Separable                                                                                 |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | separable_conv_1_reductio  (None, 56, 56, 11)           1920      []                            N         |
# | n_right1_stem_1 (Separabl                                                                                 |
# | eConv2D)                                                                                                  |
# |                                                                                                           |
# | separable_conv_1_bn_reduc  (None, 56, 56, 11)           44        []                            N         |
# | tion_left1_stem_1 (BatchN                                                                                 |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | separable_conv_1_bn_reduc  (None, 56, 56, 11)           44        []                            N         |
# | tion_right1_stem_1 (Batch                                                                                 |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | activation_2 (Activation)  (None, 56, 56, 11)           0         []                            N         |
# |                                                                                                           |
# | activation_4 (Activation)  (None, 56, 56, 11)           0         []                            N         |
# |                                                                                                           |
# | separable_conv_2_reductio  (None, 56, 56, 11)           396       []                            N         |
# | n_left1_stem_1 (Separable                                                                                 |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | separable_conv_2_reductio  (None, 56, 56, 11)           660       []                            N         |
# | n_right1_stem_1 (Separabl                                                                                 |
# | eConv2D)                                                                                                  |
# |                                                                                                           |
# | activation_5 (Activation)  (None, 111, 111, 32)         0         []                            N         |
# |                                                                                                           |
# | separable_conv_2_bn_reduc  (None, 56, 56, 11)           44        []                            N         |
# | tion_left1_stem_1 (BatchN                                                                                 |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | separable_conv_2_bn_reduc  (None, 56, 56, 11)           44        []                            N         |
# | tion_right1_stem_1 (Batch                                                                                 |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | separable_conv_1_pad_redu  (None, 117, 117, 32)         0         []                            N         |
# | ction_right2_stem_1 (Zero                                                                                 |
# | Padding2D)                                                                                                |
# |                                                                                                           |
# | activation_7 (Activation)  (None, 111, 111, 32)         0         []                            N         |
# |                                                                                                           |
# | reduction_add_1_stem_1 (A  (None, 56, 56, 11)           0         []                            N         |
# | dd)                                                                                                       |
# |                                                                                                           |
# | separable_conv_1_reductio  (None, 56, 56, 11)           1920      []                            N         |
# | n_right2_stem_1 (Separabl                                                                                 |
# | eConv2D)                                                                                                  |
# |                                                                                                           |
# | separable_conv_1_pad_redu  (None, 115, 115, 32)         0         []                            N         |
# | ction_right3_stem_1 (Zero                                                                                 |
# | Padding2D)                                                                                                |
# |                                                                                                           |
# | activation_9 (Activation)  (None, 56, 56, 11)           0         []                            N         |
# |                                                                                                           |
# | separable_conv_1_bn_reduc  (None, 56, 56, 11)           44        []                            N         |
# | tion_right2_stem_1 (Batch                                                                                 |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | separable_conv_1_reductio  (None, 56, 56, 11)           1152      []                            N         |
# | n_right3_stem_1 (Separabl                                                                                 |
# | eConv2D)                                                                                                  |
# |                                                                                                           |
# | separable_conv_1_reductio  (None, 56, 56, 11)           220       []                            N         |
# | n_left4_stem_1 (Separable                                                                                 |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | activation_6 (Activation)  (None, 56, 56, 11)           0         []                            N         |
# |                                                                                                           |
# | separable_conv_1_bn_reduc  (None, 56, 56, 11)           44        []                            N         |
# | tion_right3_stem_1 (Batch                                                                                 |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | separable_conv_1_bn_reduc  (None, 56, 56, 11)           44        []                            N         |
# | tion_left4_stem_1 (BatchN                                                                                 |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | reduction_pad_1_stem_1 (Z  (None, 113, 113, 11)         0         []                            N         |
# | eroPadding2D)                                                                                             |
# |                                                                                                           |
# | separable_conv_2_reductio  (None, 56, 56, 11)           660       []                            N         |
# | n_right2_stem_1 (Separabl                                                                                 |
# | eConv2D)                                                                                                  |
# |                                                                                                           |
# | activation_8 (Activation)  (None, 56, 56, 11)           0         []                            N         |
# |                                                                                                           |
# | activation_10 (Activation  (None, 56, 56, 11)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | reduction_left2_stem_1 (M  (None, 56, 56, 11)           0         []                            N         |
# | axPooling2D)                                                                                              |
# |                                                                                                           |
# | separable_conv_2_bn_reduc  (None, 56, 56, 11)           44        []                            N         |
# | tion_right2_stem_1 (Batch                                                                                 |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | separable_conv_2_reductio  (None, 56, 56, 11)           396       []                            N         |
# | n_right3_stem_1 (Separabl                                                                                 |
# | eConv2D)                                                                                                  |
# |                                                                                                           |
# | separable_conv_2_reductio  (None, 56, 56, 11)           220       []                            N         |
# | n_left4_stem_1 (Separable                                                                                 |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | adjust_relu_1_stem_2 (Act  (None, 111, 111, 32)         0         []                            N         |
# | ivation)                                                                                                  |
# |                                                                                                           |
# | reduction_add_2_stem_1 (A  (None, 56, 56, 11)           0         []                            N         |
# | dd)                                                                                                       |
# |                                                                                                           |
# | reduction_left3_stem_1 (A  (None, 56, 56, 11)           0         []                            N         |
# | veragePooling2D)                                                                                          |
# |                                                                                                           |
# | separable_conv_2_bn_reduc  (None, 56, 56, 11)           44        []                            N         |
# | tion_right3_stem_1 (Batch                                                                                 |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | reduction_left4_stem_1 (A  (None, 56, 56, 11)           0         []                            N         |
# | veragePooling2D)                                                                                          |
# |                                                                                                           |
# | separable_conv_2_bn_reduc  (None, 56, 56, 11)           44        []                            N         |
# | tion_left4_stem_1 (BatchN                                                                                 |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | reduction_right5_stem_1 (  (None, 56, 56, 11)           0         []                            N         |
# | MaxPooling2D)                                                                                             |
# |                                                                                                           |
# | zero_padding2d (ZeroPaddi  (None, 112, 112, 32)         0         []                            N         |
# | ng2D)                                                                                                     |
# |                                                                                                           |
# | reduction_add3_stem_1 (Ad  (None, 56, 56, 11)           0         []                            N         |
# | d)                                                                                                        |
# |                                                                                                           |
# | add (Add)                  (None, 56, 56, 11)           0         []                            N         |
# |                                                                                                           |
# | reduction_add4_stem_1 (Ad  (None, 56, 56, 11)           0         []                            N         |
# | d)                                                                                                        |
# |                                                                                                           |
# | cropping2d (Cropping2D)    (None, 111, 111, 32)         0         []                            N         |
# |                                                                                                           |
# | reduction_concat_stem_1 (  (None, 56, 56, 44)           0         []                            N         |
# | Concatenate)                                                                                              |
# |                                                                                                           |
# | adjust_avg_pool_1_stem_2   (None, 56, 56, 32)           0         []                            N         |
# | (AveragePooling2D)                                                                                        |
# |                                                                                                           |
# | adjust_avg_pool_2_stem_2   (None, 56, 56, 32)           0         []                            N         |
# | (AveragePooling2D)                                                                                        |
# |                                                                                                           |
# | activation_11 (Activation  (None, 56, 56, 44)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | adjust_conv_1_stem_2 (Con  (None, 56, 56, 11)           352       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | adjust_conv_2_stem_2 (Con  (None, 56, 56, 11)           352       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | reduction_conv_1_stem_2 (  (None, 56, 56, 22)           968       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | concatenate (Concatenate)  (None, 56, 56, 22)           0         []                            N         |
# |                                                                                                           |
# | reduction_bn_1_stem_2 (Ba  (None, 56, 56, 22)           88        []                            N         |
# | tchNormalization)                                                                                         |
# |                                                                                                           |
# | adjust_bn_stem_2 (BatchNo  (None, 56, 56, 22)           88        []                            N         |
# | rmalization)                                                                                              |
# |                                                                                                           |
# | activation_12 (Activation  (None, 56, 56, 22)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | activation_14 (Activation  (None, 56, 56, 22)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | separable_conv_1_pad_redu  (None, 59, 59, 22)           0         []                            N         |
# | ction_left1_stem_2 (ZeroP                                                                                 |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | separable_conv_1_pad_redu  (None, 61, 61, 22)           0         []                            N         |
# | ction_right1_stem_2 (Zero                                                                                 |
# | Padding2D)                                                                                                |
# |                                                                                                           |
# | separable_conv_1_reductio  (None, 28, 28, 22)           1034      []                            N         |
# | n_left1_stem_2 (Separable                                                                                 |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | separable_conv_1_reductio  (None, 28, 28, 22)           1562      []                            N         |
# | n_right1_stem_2 (Separabl                                                                                 |
# | eConv2D)                                                                                                  |
# |                                                                                                           |
# | separable_conv_1_bn_reduc  (None, 28, 28, 22)           88        []                            N         |
# | tion_left1_stem_2 (BatchN                                                                                 |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | separable_conv_1_bn_reduc  (None, 28, 28, 22)           88        []                            N         |
# | tion_right1_stem_2 (Batch                                                                                 |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | activation_13 (Activation  (None, 28, 28, 22)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | activation_15 (Activation  (None, 28, 28, 22)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | separable_conv_2_reductio  (None, 28, 28, 22)           1034      []                            N         |
# | n_left1_stem_2 (Separable                                                                                 |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | separable_conv_2_reductio  (None, 28, 28, 22)           1562      []                            N         |
# | n_right1_stem_2 (Separabl                                                                                 |
# | eConv2D)                                                                                                  |
# |                                                                                                           |
# | activation_16 (Activation  (None, 56, 56, 22)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | separable_conv_2_bn_reduc  (None, 28, 28, 22)           88        []                            N         |
# | tion_left1_stem_2 (BatchN                                                                                 |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | separable_conv_2_bn_reduc  (None, 28, 28, 22)           88        []                            N         |
# | tion_right1_stem_2 (Batch                                                                                 |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | separable_conv_1_pad_redu  (None, 61, 61, 22)           0         []                            N         |
# | ction_right2_stem_2 (Zero                                                                                 |
# | Padding2D)                                                                                                |
# |                                                                                                           |
# | activation_18 (Activation  (None, 56, 56, 22)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | reduction_add_1_stem_2 (A  (None, 28, 28, 22)           0         []                            N         |
# | dd)                                                                                                       |
# |                                                                                                           |
# | separable_conv_1_reductio  (None, 28, 28, 22)           1562      []                            N         |
# | n_right2_stem_2 (Separabl                                                                                 |
# | eConv2D)                                                                                                  |
# |                                                                                                           |
# | separable_conv_1_pad_redu  (None, 59, 59, 22)           0         []                            N         |
# | ction_right3_stem_2 (Zero                                                                                 |
# | Padding2D)                                                                                                |
# |                                                                                                           |
# | activation_20 (Activation  (None, 28, 28, 22)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | separable_conv_1_bn_reduc  (None, 28, 28, 22)           88        []                            N         |
# | tion_right2_stem_2 (Batch                                                                                 |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | separable_conv_1_reductio  (None, 28, 28, 22)           1034      []                            N         |
# | n_right3_stem_2 (Separabl                                                                                 |
# | eConv2D)                                                                                                  |
# |                                                                                                           |
# | separable_conv_1_reductio  (None, 28, 28, 22)           682       []                            N         |
# | n_left4_stem_2 (Separable                                                                                 |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | activation_17 (Activation  (None, 28, 28, 22)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | separable_conv_1_bn_reduc  (None, 28, 28, 22)           88        []                            N         |
# | tion_right3_stem_2 (Batch                                                                                 |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | separable_conv_1_bn_reduc  (None, 28, 28, 22)           88        []                            N         |
# | tion_left4_stem_2 (BatchN                                                                                 |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | reduction_pad_1_stem_2 (Z  (None, 57, 57, 22)           0         []                            N         |
# | eroPadding2D)                                                                                             |
# |                                                                                                           |
# | separable_conv_2_reductio  (None, 28, 28, 22)           1562      []                            N         |
# | n_right2_stem_2 (Separabl                                                                                 |
# | eConv2D)                                                                                                  |
# |                                                                                                           |
# | activation_19 (Activation  (None, 28, 28, 22)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | activation_21 (Activation  (None, 28, 28, 22)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | reduction_left2_stem_2 (M  (None, 28, 28, 22)           0         []                            N         |
# | axPooling2D)                                                                                              |
# |                                                                                                           |
# | separable_conv_2_bn_reduc  (None, 28, 28, 22)           88        []                            N         |
# | tion_right2_stem_2 (Batch                                                                                 |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | separable_conv_2_reductio  (None, 28, 28, 22)           1034      []                            N         |
# | n_right3_stem_2 (Separabl                                                                                 |
# | eConv2D)                                                                                                  |
# |                                                                                                           |
# | separable_conv_2_reductio  (None, 28, 28, 22)           682       []                            N         |
# | n_left4_stem_2 (Separable                                                                                 |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | adjust_relu_1_0 (Activati  (None, 56, 56, 44)           0         []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | reduction_add_2_stem_2 (A  (None, 28, 28, 22)           0         []                            N         |
# | dd)                                                                                                       |
# |                                                                                                           |
# | reduction_left3_stem_2 (A  (None, 28, 28, 22)           0         []                            N         |
# | veragePooling2D)                                                                                          |
# |                                                                                                           |
# | separable_conv_2_bn_reduc  (None, 28, 28, 22)           88        []                            N         |
# | tion_right3_stem_2 (Batch                                                                                 |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | reduction_left4_stem_2 (A  (None, 28, 28, 22)           0         []                            N         |
# | veragePooling2D)                                                                                          |
# |                                                                                                           |
# | separable_conv_2_bn_reduc  (None, 28, 28, 22)           88        []                            N         |
# | tion_left4_stem_2 (BatchN                                                                                 |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | reduction_right5_stem_2 (  (None, 28, 28, 22)           0         []                            N         |
# | MaxPooling2D)                                                                                             |
# |                                                                                                           |
# | zero_padding2d_1 (ZeroPad  (None, 57, 57, 44)           0         []                            N         |
# | ding2D)                                                                                                   |
# |                                                                                                           |
# | reduction_add3_stem_2 (Ad  (None, 28, 28, 22)           0         []                            N         |
# | d)                                                                                                        |
# |                                                                                                           |
# | add_1 (Add)                (None, 28, 28, 22)           0         []                            N         |
# |                                                                                                           |
# | reduction_add4_stem_2 (Ad  (None, 28, 28, 22)           0         []                            N         |
# | d)                                                                                                        |
# |                                                                                                           |
# | cropping2d_1 (Cropping2D)  (None, 56, 56, 44)           0         []                            N         |
# |                                                                                                           |
# | reduction_concat_stem_2 (  (None, 28, 28, 88)           0         []                            N         |
# | Concatenate)                                                                                              |
# |                                                                                                           |
# | adjust_avg_pool_1_0 (Aver  (None, 28, 28, 44)           0         []                            N         |
# | agePooling2D)                                                                                             |
# |                                                                                                           |
# | adjust_avg_pool_2_0 (Aver  (None, 28, 28, 44)           0         []                            N         |
# | agePooling2D)                                                                                             |
# |                                                                                                           |
# | adjust_conv_1_0 (Conv2D)   (None, 28, 28, 22)           968       []                            N         |
# |                                                                                                           |
# | adjust_conv_2_0 (Conv2D)   (None, 28, 28, 22)           968       []                            N         |
# |                                                                                                           |
# | activation_22 (Activation  (None, 28, 28, 88)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | concatenate_1 (Concatenat  (None, 28, 28, 44)           0         []                            N         |
# | e)                                                                                                        |
# |                                                                                                           |
# | normal_conv_1_0 (Conv2D)   (None, 28, 28, 44)           3872      []                            N         |
# |                                                                                                           |
# | adjust_bn_0 (BatchNormali  (None, 28, 28, 44)           176       []                            N         |
# | zation)                                                                                                   |
# |                                                                                                           |
# | normal_bn_1_0 (BatchNorma  (None, 28, 28, 44)           176       []                            N         |
# | lization)                                                                                                 |
# |                                                                                                           |
# | activation_23 (Activation  (None, 28, 28, 44)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | activation_25 (Activation  (None, 28, 28, 44)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | activation_27 (Activation  (None, 28, 28, 44)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | activation_29 (Activation  (None, 28, 28, 44)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | activation_31 (Activation  (None, 28, 28, 44)           0         []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | separable_conv_1_normal_l  (None, 28, 28, 44)           3036      []                            N         |
# ...
# | ation)                                                                                                    |
# |                                                                                                           |
# | normal_add_1_12 (Add)      (None, 7, 7, 176)            0         []                            N         |
# |                                                                                                           |
# | normal_add_2_12 (Add)      (None, 7, 7, 176)            0         []                            N         |
# |                                                                                                           |
# | normal_add_3_12 (Add)      (None, 7, 7, 176)            0         []                            N         |
# |                                                                                                           |
# | normal_add_4_12 (Add)      (None, 7, 7, 176)            0         []                            N         |
# |                                                                                                           |
# | normal_add_5_12 (Add)      (None, 7, 7, 176)            0         []                            N         |
# |                                                                                                           |
# | normal_concat_12 (Concate  (None, 7, 7, 1056)           0         []                            N         |
# | nate)                                                                                                     |
# |                                                                                                           |
# | activation_187 (Activatio  (None, 7, 7, 1056)           0         []                            N         |
# | n)                                                                                                        |
# |                                                                                                           |
# | global_average_pooling2d   (None, 1056)                 0         []                            N         |
# | (GlobalAveragePooling2D)                                                                                  |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  shared_layers (Functional)  (None, 2048)                 2172928   ['NASNet[0][0]']              Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_38 (InputLayer)      [(None, 1056)]               0         []                            Y         |
# |                                                                                                           |
# | flatten_3 (Flatten)        (None, 1056)                 0         []                            Y         |
# |                                                                                                           |
# | shared_dense_1 (Dense)     (None, 2048)                 2164736   []                            Y         |
# |                                                                                                           |
# | batch_normalization_39 (B  (None, 2048)                 8192      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | dropout_3 (Dropout)        (None, 2048)                 0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  category_output (Functiona  (None, 102)                  1103462   ['shared_layers[0][0]']       Y
#  l)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_39 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | category_dense_1 (Dense)   (None, 512)                  1049088   []                            Y         |
# |                                                                                                           |
# | batch_normalization_40 (B  (None, 512)                  2048      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | category_output_layer (De  (None, 102)                  52326     []                            Y         |
# | nse)                                                                                                      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  ingredients_output (Functi  (None, 1037)                 3027981   ['shared_layers[0][0]']       Y
#  onal)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_40 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | ingredients_dense_1 (Dens  (None, 1024)                 2098176   []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_41 (B  (None, 1024)                 4096      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_dense_2 (Dens  (None, 512)                  524800    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_42 (B  (None, 512)                  2048      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_dense_3 (Dens  (None, 256)                  131328    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_43 (B  (None, 256)                  1024      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_output_layer   (None, 1037)                 266509    []                            Y         |
# | (Dense)                                                                                                   |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  calorie_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_41 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | calorie_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_44 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | calorie_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_45 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | calorie_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  carbs_output (Functional)   (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_42 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | carbs_dense_1 (Dense)      (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_46 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | carbs_dense_2 (Dense)      (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_47 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | carbs_output_layer (Dense  (None, 1)                    33        []                            Y         |
# | )                                                                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  protein_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_43 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | protein_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_48 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_49 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  fat_output (Functional)     (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_44 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | fat_dense_1 (Dense)        (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_50 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_dense_2 (Dense)        (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_51 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_output_layer (Dense)   (None, 1)                    33        []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =============================================================================================================
# Total params: 11108619 (42.38 MB)
# Trainable params: 6829431 (26.05 MB)
# Non-trainable params: 4279188 (16.32 MB)
# _____________________________________________________________________________________________________________

# %%
flat_nasnet.train_model(
    x=train_dataset, validation_data=validation_dataset, epochs=10, verbose=1
)
# Out:
# Epoch 1/10
# 334/334 [==============================] - 728s 2s/step - loss: 4.2636 - category_output_loss: 2.6840 - ingredients_output_loss: 0.1599 - calorie_output_loss: 1.0190 - carbs_output_loss: 0.1524 - protein_output_loss: 0.1276 - fat_output_loss: 0.1208 - category_output_acc: 0.3563 - category_output_precision: 0.7025 - category_output_recall: 0.1911 - ingredients_output_precision: 0.0561 - ingredients_output_recall: 0.2553 - calorie_output_MAE: 1.0190 - carbs_output_MAE: 0.1524 - protein_output_MAE: 0.1276 - fat_output_MAE: 0.1208 - val_loss: 3.0905 - val_category_output_loss: 2.2439 - val_ingredients_output_loss: 0.0296 - val_calorie_output_loss: 0.5780 - val_carbs_output_loss: 0.1032 - val_protein_output_loss: 0.0491 - val_fat_output_loss: 0.0867 - val_category_output_acc: 0.4349 - val_category_output_precision: 0.7374 - val_category_output_recall: 0.2704 - val_ingredients_output_precision: 0.7724 - val_ingredients_output_recall: 0.2031 - val_calorie_output_MAE: 0.5780 - val_carbs_output_MAE: 0.1032 - val_protein_output_MAE: 0.0491 - val_fat_output_MAE: 0.0867 - lr: 0.0010
# Epoch 2/10
# 334/334 [==============================] - 689s 2s/step - loss: 3.0566 - category_output_loss: 2.2977 - ingredients_output_loss: 0.0258 - calorie_output_loss: 0.5537 - carbs_output_loss: 0.0790 - protein_output_loss: 0.0390 - fat_output_loss: 0.0613 - category_output_acc: 0.4291 - category_output_precision: 0.7420 - category_output_recall: 0.2573 - ingredients_output_precision: 0.7222 - ingredients_output_recall: 0.2839 - calorie_output_MAE: 0.5537 - carbs_output_MAE: 0.0790 - protein_output_MAE: 0.0390 - fat_output_MAE: 0.0613 - val_loss: 2.8578 - val_category_output_loss: 2.1149 - val_ingredients_output_loss: 0.0251 - val_calorie_output_loss: 0.5410 - val_carbs_output_loss: 0.0743 - val_protein_output_lo
# %% [markdown]
# ## Wide Slice Model

# %%
class WideSliceModel(BaseModel):
    def build(
        self,
        shared_units,
        independent_category_units,
        independent_protein_units,
        independent_fat_units,
        independent_carbs_units,
        independent_calorie_units,
        independent_ingredients_units,
    ):
        model_inputs = self.get_input_layer()
        prev_layer = self.get_augmentation_layers()(model_inputs)
        prev_layer = self.get_preprocess_layers(prev_layer)(prev_layer)
        conv_layer = self.get_convolution_block()(prev_layer)
        wide_slice_layer = self.get_wideslice_conv_layers(prev_layer)(prev_layer)
        prev_layer = keras.layers.Concatenate()([conv_layer, wide_slice_layer])
        prev_layer = self.get_shared_layers(prev_layer, *shared_units)(prev_layer)
        category_classification_head = self.get_category_classification_layers(
            prev_layer, self.total_food_category, *independent_category_units
        )(prev_layer)
        ingredients_multilabel_head = self.get_ingredients_multilabel_layers(
            prev_layer, self.total_ingredients_category, *independent_ingredients_units
        )(prev_layer)
        calorie_regression_head = self.get_calorie_regression_layers(
            prev_layer, *independent_calorie_units
        )(prev_layer)
        carbs_regression_head = self.get_carbs_regression_layers(
            prev_layer, *independent_carbs_units
        )(prev_layer)
        protein_regression_head = self.get_protein_regression_layers(
            prev_layer, *independent_protein_units
        )(prev_layer)
        fat_regression_head = self.get_fat_regression_layers(
            prev_layer, *independent_fat_units
        )(prev_layer)

        model = keras.Model(
            inputs=model_inputs,
            outputs=[
                category_classification_head,
                ingredients_multilabel_head,
                calorie_regression_head,
                carbs_regression_head,
                protein_regression_head,
                fat_regression_head,
            ],
            name=self.name,
        )
        self.model = model

    def get_wideslice_conv_layers(self, input_tensor):
        input_layer = keras.layers.Input(shape=input_tensor.shape[1:])
        rescale_layer = keras.layers.Rescaling(scale=1.0 / 255)(input_layer)
        wideslice_conv = keras.layers.Conv2D(filters=64, kernel_size=(5, 224))(
            rescale_layer
        )
        wideslice_conv = keras.layers.BatchNormalization()(wideslice_conv)
        wideslice_conv = keras.layers.ReLU()(wideslice_conv)
        wideslice_conv = keras.layers.GlobalMaxPool2D()(wideslice_conv)
        return keras.Model(
            inputs=input_layer, outputs=wideslice_conv, name="wideslice_conv"
        )

# %% [markdown]
# ### EfficientNetB1

# %%
class WideSliceEfficientNetModel(WideSliceModel):
    def __init__(
        self,
        input_shape,
        total_food_category,
        total_ingredients_category,
        model_config_name,
    ):
        super().__init__(
            input_shape,
            total_food_category,
            total_ingredients_category,
            "wideslice_efficientnetB1",
            model_config_name,
        )

    def get_preprocess_layers(self, input_tensor):
        input_layer = keras.layers.Input(shape=input_tensor.shape[1:])
        output_layer = keras.applications.efficientnet.preprocess_input(input_layer)
        return keras.Model(
            inputs=input_layer, outputs=output_layer, name="preprocessing_layers"
        )

    def get_convolution_block(self):
        efficientnet_convolution_layers = (
            keras.applications.efficientnet.EfficientNetB1(
                input_shape=self.input_shape,
                include_top=False,
                weights="imagenet",
                pooling="avg",
            )
        )
        efficientnet_convolution_layers.trainable = False
        return efficientnet_convolution_layers

# %% [markdown]
# #### Train on main dataset (recipes5k + food101 + nutrition5k)

# %%
wideslice_efficientnet = WideSliceEfficientNetModel(
    input_shape=(224, 224, 3),
    total_food_category=len(data_pipeline.one_hot_encoder.all_food_categories),
    total_ingredients_category=len(data_pipeline.one_hot_encoder.all_ingredients),
    model_config_name="finalCategoryNoTransfer",
)

wideslice_efficientnet.build(
    shared_units=[2048],
    independent_category_units=[512],
    independent_protein_units=[64, 32],
    independent_fat_units=[64, 32],
    independent_carbs_units=[64, 32],
    independent_calorie_units=[64, 32],
    independent_ingredients_units=[1024, 512, 256],
)
wideslice_efficientnet.compile_model(keras.optimizers.Adam())
wideslice_efficientnet.print_summary()
# Out:
# Model: "wideslice_efficientnetB1"
# _____________________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to                  Trainable
# =============================================================================================================
#  input_45 (InputLayer)       [(None, 224, 224, 3)]        0         []                            Y
#
#  augmentation_layers (Funct  (None, 224, 224, 3)          0         ['input_45[0][0]']            Y
#  ional)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_46 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# |                                                                                                           |
# | random_flip_4 (RandomFlip  (None, 224, 224, 3)          0         []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | random_rotation_4 (Random  (None, 224, 224, 3)          0         []                            Y         |
# | Rotation)                                                                                                 |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  preprocessing_layers (Func  (None, 224, 224, 3)          0         ['augmentation_layers[0][0]   Y
#  tional)                                                            ']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_47 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  efficientnetb1 (Functional  (None, 1280)                 6575239   ['preprocessing_layers[0][0   N
#  )                                                                  ]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_48 (InputLayer)      [(None, 224, 224, 3)]        0         []                            N         |
# |                                                                                                           |
# | rescaling_5 (Rescaling)    (None, 224, 224, 3)          0         []                            N         |
# |                                                                                                           |
# | normalization_2 (Normaliz  (None, 224, 224, 3)          7         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | rescaling_6 (Rescaling)    (None, 224, 224, 3)          0         []                            N         |
# |                                                                                                           |
# | stem_conv_pad (ZeroPaddin  (None, 225, 225, 3)          0         []                            N         |
# | g2D)                                                                                                      |
# |                                                                                                           |
# | stem_conv (Conv2D)         (None, 112, 112, 32)         864       []                            N         |
# |                                                                                                           |
# | stem_bn (BatchNormalizati  (None, 112, 112, 32)         128       []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | stem_activation (Activati  (None, 112, 112, 32)         0         []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | block1a_dwconv (Depthwise  (None, 112, 112, 32)         288       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block1a_bn (BatchNormaliz  (None, 112, 112, 32)         128       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1a_activation (Activ  (None, 112, 112, 32)         0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1a_se_squeeze (Globa  (None, 32)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block1a_se_reshape (Resha  (None, 1, 1, 32)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block1a_se_reduce (Conv2D  (None, 1, 1, 8)              264       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1a_se_expand (Conv2D  (None, 1, 1, 32)             288       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1a_se_excite (Multip  (None, 112, 112, 32)         0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block1a_project_conv (Con  (None, 112, 112, 16)         512       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block1a_project_bn (Batch  (None, 112, 112, 16)         64        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block1b_dwconv (Depthwise  (None, 112, 112, 16)         144       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block1b_bn (BatchNormaliz  (None, 112, 112, 16)         64        []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1b_activation (Activ  (None, 112, 112, 16)         0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1b_se_squeeze (Globa  (None, 16)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block1b_se_reshape (Resha  (None, 1, 1, 16)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block1b_se_reduce (Conv2D  (None, 1, 1, 4)              68        []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1b_se_expand (Conv2D  (None, 1, 1, 16)             80        []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1b_se_excite (Multip  (None, 112, 112, 16)         0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block1b_project_conv (Con  (None, 112, 112, 16)         256       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block1b_project_bn (Batch  (None, 112, 112, 16)         64        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block1b_drop (Dropout)     (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | block1b_add (Add)          (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | block2a_expand_conv (Conv  (None, 112, 112, 96)         1536      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2a_expand_bn (BatchN  (None, 112, 112, 96)         384       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2a_expand_activation  (None, 112, 112, 96)         0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2a_dwconv_pad (ZeroP  (None, 113, 113, 96)         0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block2a_dwconv (Depthwise  (None, 56, 56, 96)           864       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2a_bn (BatchNormaliz  (None, 56, 56, 96)           384       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2a_activation (Activ  (None, 56, 56, 96)           0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2a_se_squeeze (Globa  (None, 96)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2a_se_reshape (Resha  (None, 1, 1, 96)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2a_se_reduce (Conv2D  (None, 1, 1, 4)              388       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2a_se_expand (Conv2D  (None, 1, 1, 96)             480       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2a_se_excite (Multip  (None, 56, 56, 96)           0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2a_project_conv (Con  (None, 56, 56, 24)           2304      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2a_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2b_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2b_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2b_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2b_dwconv (Depthwise  (None, 56, 56, 144)          1296      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2b_bn (BatchNormaliz  (None, 56, 56, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2b_activation (Activ  (None, 56, 56, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2b_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2b_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2b_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2b_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2b_se_excite (Multip  (None, 56, 56, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2b_project_conv (Con  (None, 56, 56, 24)           3456      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2b_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2b_drop (Dropout)     (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2b_add (Add)          (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2c_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2c_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2c_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2c_dwconv (Depthwise  (None, 56, 56, 144)          1296      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2c_bn (BatchNormaliz  (None, 56, 56, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2c_activation (Activ  (None, 56, 56, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2c_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2c_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2c_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2c_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2c_se_excite (Multip  (None, 56, 56, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2c_project_conv (Con  (None, 56, 56, 24)           3456      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2c_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2c_drop (Dropout)     (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2c_add (Add)          (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block3a_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3a_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3a_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3a_dwconv_pad (ZeroP  (None, 59, 59, 144)          0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block3a_dwconv (Depthwise  (None, 28, 28, 144)          3600      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3a_bn (BatchNormaliz  (None, 28, 28, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3a_activation (Activ  (None, 28, 28, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3a_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3a_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3a_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3a_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3a_se_excite (Multip  (None, 28, 28, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3a_project_conv (Con  (None, 28, 28, 40)           5760      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3a_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3b_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3b_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3b_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3b_dwconv (Depthwise  (None, 28, 28, 240)          6000      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3b_bn (BatchNormaliz  (None, 28, 28, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3b_activation (Activ  (None, 28, 28, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3b_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3b_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3b_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3b_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3b_se_excite (Multip  (None, 28, 28, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3b_project_conv (Con  (None, 28, 28, 40)           9600      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3b_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3b_drop (Dropout)     (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3b_add (Add)          (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3c_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3c_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3c_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3c_dwconv (Depthwise  (None, 28, 28, 240)          6000      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3c_bn (BatchNormaliz  (None, 28, 28, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3c_activation (Activ  (None, 28, 28, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3c_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3c_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3c_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3c_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3c_se_excite (Multip  (None, 28, 28, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3c_project_conv (Con  (None, 28, 28, 40)           9600      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3c_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3c_drop (Dropout)     (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3c_add (Add)          (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block4a_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block4a_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block4a_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block4a_dwconv_pad (ZeroP  (None, 29, 29, 240)          0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block4a_dwconv (Depthwise  (None, 14, 14, 240)          2160      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block4a_bn (BatchNormaliz  (None, 14, 14, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4a_activation (Activ  (None, 14, 14, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4a_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block4a_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block4a_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4a_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4a_se_excite (Multip  (None, 14, 14, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block4a_project_conv (Con  (None, 14, 14, 80)           19200     []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block4a_project_bn (Batch  (None, 14, 14, 80)           320       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block4b_expand_conv (Conv  (None, 14, 14, 480)          38400     []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block4b_expand_bn (BatchN  (None, 14, 14, 480)          1920      []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block4b_expand_activation  (None, 14, 14, 480)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block4b_dwconv (Depthwise  (None, 14, 14, 480)          4320      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block4b_bn (BatchNormaliz  (None, 14, 14, 480)          1920      []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4b_activation (Activ  (None, 14, 14, 480)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4b_se_squeeze (Globa  (None, 480)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block4b_se_reshape (Resha  (None, 1, 1, 480)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block4b_se_reduce (Conv2D  (None, 1, 1, 20)             9620      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4b_se_expand (Conv2D  (None, 1, 1, 480)            10080     []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# ...
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  wideslice_conv (Functional  (None, 64)                   215360    ['preprocessing_layers[0][0   Y
#  )                                                                  ]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_49 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# |                                                                                                           |
# | rescaling_7 (Rescaling)    (None, 224, 224, 3)          0         []                            Y         |
# |                                                                                                           |
# | conv2d (Conv2D)            (None, 220, 1, 64)           215104    []                            Y         |
# |                                                                                                           |
# | batch_normalization_52 (B  (None, 220, 1, 64)           256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | re_lu_39 (ReLU)            (None, 220, 1, 64)           0         []                            Y         |
# |                                                                                                           |
# | global_max_pooling2d (Glo  (None, 64)                   0         []                            Y         |
# | balMaxPooling2D)                                                                                          |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  concatenate_4 (Concatenate  (None, 1344)                 0         ['efficientnetb1[0][0]',      Y
#  )                                                                   'wideslice_conv[0][0]']
#
#  shared_layers (Functional)  (None, 2048)                 2762752   ['concatenate_4[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_50 (InputLayer)      [(None, 1344)]               0         []                            Y         |
# |                                                                                                           |
# | flatten_4 (Flatten)        (None, 1344)                 0         []                            Y         |
# |                                                                                                           |
# | shared_dense_1 (Dense)     (None, 2048)                 2754560   []                            Y         |
# |                                                                                                           |
# | batch_normalization_53 (B  (None, 2048)                 8192      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | dropout_4 (Dropout)        (None, 2048)                 0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  category_output (Functiona  (None, 102)                  1103462   ['shared_layers[0][0]']       Y
#  l)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_51 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | category_dense_1 (Dense)   (None, 512)                  1049088   []                            Y         |
# |                                                                                                           |
# | batch_normalization_54 (B  (None, 512)                  2048      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | category_output_layer (De  (None, 102)                  52326     []                            Y         |
# | nse)                                                                                                      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  ingredients_output (Functi  (None, 1037)                 3027981   ['shared_layers[0][0]']       Y
#  onal)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_52 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | ingredients_dense_1 (Dens  (None, 1024)                 2098176   []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_55 (B  (None, 1024)                 4096      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_dense_2 (Dens  (None, 512)                  524800    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_56 (B  (None, 512)                  2048      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_dense_3 (Dens  (None, 256)                  131328    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_57 (B  (None, 256)                  1024      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_output_layer   (None, 1037)                 266509    []                            Y         |
# | (Dense)                                                                                                   |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  calorie_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_53 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | calorie_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_58 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | calorie_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_59 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | calorie_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  carbs_output (Functional)   (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_54 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | carbs_dense_1 (Dense)      (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_60 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | carbs_dense_2 (Dense)      (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_61 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | carbs_output_layer (Dense  (None, 1)                    33        []                            Y         |
# | )                                                                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  protein_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_55 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | protein_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_62 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_63 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  fat_output (Functional)     (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_56 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | fat_dense_1 (Dense)        (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_64 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_dense_2 (Dense)        (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_65 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_output_layer (Dense)   (None, 1)                    33        []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =============================================================================================================
# Total params: 14219326 (54.24 MB)
# Trainable params: 7634487 (29.12 MB)
# Non-trainable params: 6584839 (25.12 MB)
# _____________________________________________________________________________________________________________

# %%
wideslice_efficientnet.train_model(
    x=train_dataset, epochs=25, verbose=2, validation_data=validation_dataset
)
# Out:
# Epoch 1/25
# 334/334 - 735s - loss: 2.7323 - category_output_loss: 1.9074 - ingredients_output_loss: 0.0311 - calorie_output_loss: 0.5849 - carbs_output_loss: 0.0832 - protein_output_loss: 0.0490 - fat_output_loss: 0.0767 - category_output_acc: 0.5218 - category_output_precision: 0.7672 - category_output_recall: 0.3737 - ingredients_output_precision: 0.7224 - ingredients_output_recall: 0.2617 - calorie_output_MAE: 0.5849 - carbs_output_MAE: 0.0832 - protein_output_MAE: 0.0490 - fat_output_MAE: 0.0767 - val_loss: 2.3216 - val_category_output_loss: 1.5960 - val_ingredients_output_loss: 0.0248 - val_calorie_output_loss: 0.5300 - val_carbs_output_loss: 0.0716 - val_protein_output_loss: 0.0334 - val_fat_output_loss: 0.0659 - val_category_output_acc: 0.5894 - val_category_output_precision: 0.7824 - val_category_output_recall: 0.4759 - val_ingredients_output_precision: 0.8025 - val_ingredients_output_recall: 0.3388 - val_calorie_output_MAE: 0.5300 - val_carbs_output_MAE: 0.0716 - val_protein_output_MAE: 0.0334 - val_fat_output_MAE: 0.0659 - lr: 0.0010 - 735s/epoch - 2s/step
# Epoch 13/25
# 334/334 - 729s - loss: 1.3676 - category_output_loss: 0.7824 - ingredients_output_loss: 0.0163 - calorie_output_loss: 0.4445 - carbs_output_loss: 0.0568 - protein_output_loss: 0.0193 - fat_output_loss: 0.0483 - category_output_acc: 0.7777 - category_output_precision: 0.8891 - category_output_recall: 0.6881 - ingredients_output_precision: 0.8644 - ingredients_output_recall: 0.5777 - calorie_output_MAE: 0.4445 - carbs_output_MAE: 0.0568 - protein_output_MAE: 0.0193 - fat_output_MAE: 0.0483 - val_loss: 1.8499 - val_category_output_loss: 1.2541 - val_ingredients_output_loss: 0.0171 - val_calorie_output_loss: 0.4572 - val_carbs_output_loss: 0.0552 - val_protein_output_loss: 0.0188 - val_fat_output_loss: 0.0476 - val_category_output_acc: 0.6800 - val_category_output_precision: 0.8002 - val_category_output_recall: 0.6190 - val_ingredients_output_precision: 0.8419 - val_ingredients_output_recall: 0.5758 - val_calorie_output_MAE: 0.4572 - val_carbs_output_MAE: 0.0552 - val_protein_output_MAE: 0.0188 - val_fat_output_MAE: 0.0476 - lr: 2.5000e-04 - 729s/epoch - 2s/step
# Epoch 14/25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-dd1119a82a37> in <cell line: 1>()
# ----> 1 wideslice_efficientnet.train_model(
#       2     x=train_dataset, epochs=25, verbose=2, validation_data=validation_dataset
#       3 )
#
# <ipython-input-23-ac51324a228a> in train_model(self, **kwargs)
#     280     def train_model(self, **kwargs):
#     281         assert self.model is not None, "No model found."
# --> 282         return self.model.fit(**kwargs, callbacks=self.get_callbacks())
#     283
#     284     def unfreeze_category_classification_layers(self):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1854                             pss_evaluation_shards=self._pss_evaluation_shards,
#    1855                         )
# -> 1856                     val_logs = self.evaluate(
#    1857                         x=val_x,
#    1858                         y=val_y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2294                         ):
#    2295                             callbacks.on_test_batch_begin(step)
# -> 2296                             logs = test_function_runner.run_step(
#    2297                                 dataset_or_iterator,
#    2298                                 data_handler,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in run_step(self, dataset_or_iterator, data_handler, step, unused_shards)
#    4106
#    4107     def run_step(self, dataset_or_iterator, data_handler, step, unused_shards):
# -> 4108         tmp_logs = self._function(dataset_or_iterator)
#    4109         if data_handler.should_sync:
#    4110             context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     875       # In this case we have not created variables on the first call. So we can
#     876       # run the first trace but we should fail if variables are created.
# --> 877       results = tracing_compilation.call_function(
#     878           args, kwds, self._variable_creation_config
#     879       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Transfer weights from fine tuned flat model

# %%
fine_tuned_flat_efficientnet = keras.models.load_model(
    "/content/food_v5/main/temp/checkpoint/flat_efficientnetB1/finalCategoryNoTransferFineTuned/model"
)
fine_tuned_efficientnet_weights = fine_tuned_flat_efficientnet.get_layer(
    "efficientnetb1"
).get_weights()

# %%
wideslice_efficientnet = WideSliceEfficientNetModel(
    input_shape=(224, 224, 3),
    total_food_category=len(data_pipeline.one_hot_encoder.all_food_categories),
    total_ingredients_category=len(data_pipeline.one_hot_encoder.all_ingredients),
    model_config_name="finalCategoryNoTransferFineTuned",
)

wideslice_efficientnet.load_model(
    "/content/food_v5/main/temp/checkpoint/wideslice_efficientnetB1/finalCategoryNoTransfer/model"
)
wideslice_efficientnet.unfreeze_convolution_base(117)
wideslice_efficientnet.model.get_layer("efficientnetb1").set_weights(
    fine_tuned_efficientnet_weights
)
wideslice_efficientnet.compile_model(keras.optimizers.Adam(learning_rate=1e-5))
wideslice_efficientnet.print_summary()
# Out:
# Model: "wideslice_efficientnetB1"
# _____________________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to                  Trainable
# =============================================================================================================
#  input_45 (InputLayer)       [(None, 224, 224, 3)]        0         []                            Y
#
#  augmentation_layers (Funct  (None, 224, 224, 3)          0         ['input_45[0][0]']            Y
#  ional)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_46 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# |                                                                                                           |
# | random_flip_4 (RandomFlip  (None, 224, 224, 3)          0         []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | random_rotation_4 (Random  (None, 224, 224, 3)          0         []                            Y         |
# | Rotation)                                                                                                 |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  preprocessing_layers (Func  (None, 224, 224, 3)          0         ['augmentation_layers[0][0]   Y
#  tional)                                                            ']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_47 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  efficientnetb1 (Functional  (None, 1280)                 6575239   ['preprocessing_layers[0][0   Y
#  )                                                                  ]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_48 (InputLayer)      [(None, 224, 224, 3)]        0         []                            N         |
# |                                                                                                           |
# | rescaling_5 (Rescaling)    (None, 224, 224, 3)          0         []                            N         |
# |                                                                                                           |
# | normalization_2 (Normaliz  (None, 224, 224, 3)          7         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | rescaling_6 (Rescaling)    (None, 224, 224, 3)          0         []                            N         |
# |                                                                                                           |
# | stem_conv_pad (ZeroPaddin  (None, 225, 225, 3)          0         []                            N         |
# | g2D)                                                                                                      |
# |                                                                                                           |
# | stem_conv (Conv2D)         (None, 112, 112, 32)         864       []                            N         |
# |                                                                                                           |
# | stem_bn (BatchNormalizati  (None, 112, 112, 32)         128       []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | stem_activation (Activati  (None, 112, 112, 32)         0         []                            N         |
# | on)                                                                                                       |
# |                                                                                                           |
# | block1a_dwconv (Depthwise  (None, 112, 112, 32)         288       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block1a_bn (BatchNormaliz  (None, 112, 112, 32)         128       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1a_activation (Activ  (None, 112, 112, 32)         0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1a_se_squeeze (Globa  (None, 32)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block1a_se_reshape (Resha  (None, 1, 1, 32)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block1a_se_reduce (Conv2D  (None, 1, 1, 8)              264       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1a_se_expand (Conv2D  (None, 1, 1, 32)             288       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1a_se_excite (Multip  (None, 112, 112, 32)         0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block1a_project_conv (Con  (None, 112, 112, 16)         512       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block1a_project_bn (Batch  (None, 112, 112, 16)         64        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block1b_dwconv (Depthwise  (None, 112, 112, 16)         144       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block1b_bn (BatchNormaliz  (None, 112, 112, 16)         64        []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1b_activation (Activ  (None, 112, 112, 16)         0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block1b_se_squeeze (Globa  (None, 16)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block1b_se_reshape (Resha  (None, 1, 1, 16)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block1b_se_reduce (Conv2D  (None, 1, 1, 4)              68        []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1b_se_expand (Conv2D  (None, 1, 1, 16)             80        []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block1b_se_excite (Multip  (None, 112, 112, 16)         0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block1b_project_conv (Con  (None, 112, 112, 16)         256       []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block1b_project_bn (Batch  (None, 112, 112, 16)         64        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block1b_drop (Dropout)     (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | block1b_add (Add)          (None, 112, 112, 16)         0         []                            N         |
# |                                                                                                           |
# | block2a_expand_conv (Conv  (None, 112, 112, 96)         1536      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2a_expand_bn (BatchN  (None, 112, 112, 96)         384       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2a_expand_activation  (None, 112, 112, 96)         0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2a_dwconv_pad (ZeroP  (None, 113, 113, 96)         0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block2a_dwconv (Depthwise  (None, 56, 56, 96)           864       []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2a_bn (BatchNormaliz  (None, 56, 56, 96)           384       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2a_activation (Activ  (None, 56, 56, 96)           0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2a_se_squeeze (Globa  (None, 96)                   0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2a_se_reshape (Resha  (None, 1, 1, 96)             0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2a_se_reduce (Conv2D  (None, 1, 1, 4)              388       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2a_se_expand (Conv2D  (None, 1, 1, 96)             480       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2a_se_excite (Multip  (None, 56, 56, 96)           0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2a_project_conv (Con  (None, 56, 56, 24)           2304      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2a_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2b_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2b_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2b_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2b_dwconv (Depthwise  (None, 56, 56, 144)          1296      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2b_bn (BatchNormaliz  (None, 56, 56, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2b_activation (Activ  (None, 56, 56, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2b_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2b_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2b_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2b_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2b_se_excite (Multip  (None, 56, 56, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2b_project_conv (Con  (None, 56, 56, 24)           3456      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2b_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2b_drop (Dropout)     (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2b_add (Add)          (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2c_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block2c_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block2c_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block2c_dwconv (Depthwise  (None, 56, 56, 144)          1296      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block2c_bn (BatchNormaliz  (None, 56, 56, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2c_activation (Activ  (None, 56, 56, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block2c_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block2c_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block2c_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2c_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block2c_se_excite (Multip  (None, 56, 56, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block2c_project_conv (Con  (None, 56, 56, 24)           3456      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block2c_project_bn (Batch  (None, 56, 56, 24)           96        []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block2c_drop (Dropout)     (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block2c_add (Add)          (None, 56, 56, 24)           0         []                            N         |
# |                                                                                                           |
# | block3a_expand_conv (Conv  (None, 56, 56, 144)          3456      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3a_expand_bn (BatchN  (None, 56, 56, 144)          576       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3a_expand_activation  (None, 56, 56, 144)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3a_dwconv_pad (ZeroP  (None, 59, 59, 144)          0         []                            N         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block3a_dwconv (Depthwise  (None, 28, 28, 144)          3600      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3a_bn (BatchNormaliz  (None, 28, 28, 144)          576       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3a_activation (Activ  (None, 28, 28, 144)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3a_se_squeeze (Globa  (None, 144)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3a_se_reshape (Resha  (None, 1, 1, 144)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3a_se_reduce (Conv2D  (None, 1, 1, 6)              870       []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3a_se_expand (Conv2D  (None, 1, 1, 144)            1008      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3a_se_excite (Multip  (None, 28, 28, 144)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3a_project_conv (Con  (None, 28, 28, 40)           5760      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3a_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3b_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3b_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3b_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3b_dwconv (Depthwise  (None, 28, 28, 240)          6000      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3b_bn (BatchNormaliz  (None, 28, 28, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3b_activation (Activ  (None, 28, 28, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3b_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3b_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3b_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3b_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3b_se_excite (Multip  (None, 28, 28, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3b_project_conv (Con  (None, 28, 28, 40)           9600      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3b_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3b_drop (Dropout)     (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3b_add (Add)          (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3c_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            N         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block3c_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            N         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block3c_expand_activation  (None, 28, 28, 240)          0         []                            N         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block3c_dwconv (Depthwise  (None, 28, 28, 240)          6000      []                            N         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block3c_bn (BatchNormaliz  (None, 28, 28, 240)          960       []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3c_activation (Activ  (None, 28, 28, 240)          0         []                            N         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block3c_se_squeeze (Globa  (None, 240)                  0         []                            N         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block3c_se_reshape (Resha  (None, 1, 1, 240)            0         []                            N         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block3c_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3c_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            N         |
# | )                                                                                                         |
# |                                                                                                           |
# | block3c_se_excite (Multip  (None, 28, 28, 240)          0         []                            N         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block3c_project_conv (Con  (None, 28, 28, 40)           9600      []                            N         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block3c_project_bn (Batch  (None, 28, 28, 40)           160       []                            N         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block3c_drop (Dropout)     (None, 28, 28, 40)           0         []                            N         |
# |                                                                                                           |
# | block3c_add (Add)          (None, 28, 28, 40)           0         []                            Y         |
# |                                                                                                           |
# | block4a_expand_conv (Conv  (None, 28, 28, 240)          9600      []                            Y         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block4a_expand_bn (BatchN  (None, 28, 28, 240)          960       []                            Y         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block4a_expand_activation  (None, 28, 28, 240)          0         []                            Y         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block4a_dwconv_pad (ZeroP  (None, 29, 29, 240)          0         []                            Y         |
# | adding2D)                                                                                                 |
# |                                                                                                           |
# | block4a_dwconv (Depthwise  (None, 14, 14, 240)          2160      []                            Y         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block4a_bn (BatchNormaliz  (None, 14, 14, 240)          960       []                            Y         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4a_activation (Activ  (None, 14, 14, 240)          0         []                            Y         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4a_se_squeeze (Globa  (None, 240)                  0         []                            Y         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block4a_se_reshape (Resha  (None, 1, 1, 240)            0         []                            Y         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block4a_se_reduce (Conv2D  (None, 1, 1, 10)             2410      []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4a_se_expand (Conv2D  (None, 1, 1, 240)            2640      []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4a_se_excite (Multip  (None, 14, 14, 240)          0         []                            Y         |
# | ly)                                                                                                       |
# |                                                                                                           |
# | block4a_project_conv (Con  (None, 14, 14, 80)           19200     []                            Y         |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | block4a_project_bn (Batch  (None, 14, 14, 80)           320       []                            Y         |
# | Normalization)                                                                                            |
# |                                                                                                           |
# | block4b_expand_conv (Conv  (None, 14, 14, 480)          38400     []                            Y         |
# | 2D)                                                                                                       |
# |                                                                                                           |
# | block4b_expand_bn (BatchN  (None, 14, 14, 480)          1920      []                            Y         |
# | ormalization)                                                                                             |
# |                                                                                                           |
# | block4b_expand_activation  (None, 14, 14, 480)          0         []                            Y         |
# |  (Activation)                                                                                             |
# |                                                                                                           |
# | block4b_dwconv (Depthwise  (None, 14, 14, 480)          4320      []                            Y         |
# | Conv2D)                                                                                                   |
# |                                                                                                           |
# | block4b_bn (BatchNormaliz  (None, 14, 14, 480)          1920      []                            Y         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4b_activation (Activ  (None, 14, 14, 480)          0         []                            Y         |
# | ation)                                                                                                    |
# |                                                                                                           |
# | block4b_se_squeeze (Globa  (None, 480)                  0         []                            Y         |
# | lAveragePooling2D)                                                                                        |
# |                                                                                                           |
# | block4b_se_reshape (Resha  (None, 1, 1, 480)            0         []                            Y         |
# | pe)                                                                                                       |
# |                                                                                                           |
# | block4b_se_reduce (Conv2D  (None, 1, 1, 20)             9620      []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# | block4b_se_expand (Conv2D  (None, 1, 1, 480)            10080     []                            Y         |
# | )                                                                                                         |
# |                                                                                                           |
# ...
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  wideslice_conv (Functional  (None, 64)                   215360    ['preprocessing_layers[0][0   Y
#  )                                                                  ]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_49 (InputLayer)      [(None, 224, 224, 3)]        0         []                            Y         |
# |                                                                                                           |
# | rescaling_7 (Rescaling)    (None, 224, 224, 3)          0         []                            Y         |
# |                                                                                                           |
# | conv2d (Conv2D)            (None, 220, 1, 64)           215104    []                            Y         |
# |                                                                                                           |
# | batch_normalization_52 (B  (None, 220, 1, 64)           256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | re_lu_39 (ReLU)            (None, 220, 1, 64)           0         []                            Y         |
# |                                                                                                           |
# | global_max_pooling2d (Glo  (None, 64)                   0         []                            Y         |
# | balMaxPooling2D)                                                                                          |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  concatenate_4 (Concatenate  (None, 1344)                 0         ['efficientnetb1[0][0]',      Y
#  )                                                                   'wideslice_conv[0][0]']
#
#  shared_layers (Functional)  (None, 2048)                 2762752   ['concatenate_4[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_50 (InputLayer)      [(None, 1344)]               0         []                            Y         |
# |                                                                                                           |
# | flatten_4 (Flatten)        (None, 1344)                 0         []                            Y         |
# |                                                                                                           |
# | shared_dense_1 (Dense)     (None, 2048)                 2754560   []                            Y         |
# |                                                                                                           |
# | batch_normalization_53 (B  (None, 2048)                 8192      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | dropout_4 (Dropout)        (None, 2048)                 0         []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  category_output (Functiona  (None, 102)                  1103462   ['shared_layers[0][0]']       Y
#  l)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_51 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | category_dense_1 (Dense)   (None, 512)                  1049088   []                            Y         |
# |                                                                                                           |
# | batch_normalization_54 (B  (None, 512)                  2048      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | category_output_layer (De  (None, 102)                  52326     []                            Y         |
# | nse)                                                                                                      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  ingredients_output (Functi  (None, 1037)                 3027981   ['shared_layers[0][0]']       Y
#  onal)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_52 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | ingredients_dense_1 (Dens  (None, 1024)                 2098176   []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_55 (B  (None, 1024)                 4096      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_dense_2 (Dens  (None, 512)                  524800    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_56 (B  (None, 512)                  2048      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_dense_3 (Dens  (None, 256)                  131328    []                            Y         |
# | e)                                                                                                        |
# |                                                                                                           |
# | batch_normalization_57 (B  (None, 256)                  1024      []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | ingredients_output_layer   (None, 1037)                 266509    []                            Y         |
# | (Dense)                                                                                                   |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  calorie_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_53 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | calorie_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_58 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | calorie_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_59 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | calorie_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  carbs_output (Functional)   (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_54 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | carbs_dense_1 (Dense)      (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_60 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | carbs_dense_2 (Dense)      (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_61 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | carbs_output_layer (Dense  (None, 1)                    33        []                            Y         |
# | )                                                                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  protein_output (Functional  (None, 1)                    133633    ['shared_layers[0][0]']       Y
#  )
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_55 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | protein_dense_1 (Dense)    (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_62 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_dense_2 (Dense)    (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_63 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | protein_output_layer (Den  (None, 1)                    33        []                            Y         |
# | se)                                                                                                       |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  fat_output (Functional)     (None, 1)                    133633    ['shared_layers[0][0]']       Y
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | input_56 (InputLayer)      [(None, 2048)]               0         []                            Y         |
# |                                                                                                           |
# | fat_dense_1 (Dense)        (None, 64)                   131136    []                            Y         |
# |                                                                                                           |
# | batch_normalization_64 (B  (None, 64)                   256       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_dense_2 (Dense)        (None, 32)                   2080      []                            Y         |
# |                                                                                                           |
# | batch_normalization_65 (B  (None, 32)                   128       []                            Y         |
# | atchNormalization)                                                                                        |
# |                                                                                                           |
# | fat_output_layer (Dense)   (None, 1)                    33        []                            Y         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =============================================================================================================
# Total params: 14219326 (54.24 MB)
# Trainable params: 14039329 (53.56 MB)
# Non-trainable params: 179997 (703.12 KB)
# _____________________________________________________________________________________________________________

# %%
wideslice_efficientnet.train_model(
    x=train_dataset,
    epochs=20,
    verbose=2,
    validation_data=validation_dataset,
)
# Out:
# Epoch 1/20
# 334/334 - 963s - loss: 1.6459 - category_output_loss: 1.0384 - ingredients_output_loss: 0.0173 - calorie_output_loss: 0.4629 - carbs_output_loss: 0.0583 - protein_output_loss: 0.0197 - fat_output_loss: 0.0494 - category_output_acc: 0.7089 - category_output_precision: 0.8267 - category_output_recall: 0.6308 - ingredients_output_precision: 0.8331 - ingredients_output_recall: 0.5608 - calorie_output_MAE: 0.4629 - carbs_output_MAE: 0.0583 - protein_output_MAE: 0.0197 - fat_output_MAE: 0.0494 - val_loss: 1.9342 - val_category_output_loss: 1.3315 - val_ingredients_output_loss: 0.0173 - val_calorie_output_loss: 0.4628 - val_carbs_output_loss: 0.0557 - val_protein_output_loss: 0.0189 - val_fat_output_loss: 0.0481 - val_category_output_acc: 0.6727 - val_category_output_precision: 0.7869 - val_category_output_recall: 0.6138 - val_ingredients_output_precision: 0.8389 - val_ingredients_output_recall: 0.5730 - val_calorie_output_MAE: 0.4628 - val_carbs_output_MAE: 0.0557 - val_protein_output_MAE: 0.0189 - val_fat_output_MAE: 0.0481 - lr: 1.0000e-05 - 963s/epoch - 3s/step
# Epoch 2/20
# 334/334 - 918s - loss: 1.5380 - category_output_loss: 0.9405 - ingredients_output_loss: 0.0168 - calorie_output_loss: 0.4554 - carbs_output_loss: 0.0571 - protein_output_loss: 0.0194 - fat_output_loss: 0.0488 - category_output_acc: 0.7343 - category_output_precision: 0.8467 - category_output_recall: 0.6594 - ingredients_output_precision: 0.8461 - ingredients_output_recall: 0.5715 - calorie_output_MAE: 0.4554 - carbs_output_MAE: 0.0571 - protein_output_MAE: 0.0194 - fat_output_MAE: 0.
output_loss: 0.0179 - val_fat_output_loss: 0.0459 - val_category_output_acc: 0.7272 - val_category_output_precision: 0.8288 - val_category_output_recall: 0.6733 - val_ingredients_output_precision: 0.8696 - val_ingredients_output_recall: 0.6003 - val_calorie_output_MAE: 0.4401 - val_carbs_output_MAE: 0.0522 - val_protein_output_MAE: 0.0179 - val_fat_output_MAE: 0.0459 - lr: 1.0000e-05 - 923s/epoch - 3s/step
# Epoch 19/20
# 334/334 - 921s - loss: 1.0647 - category_output_loss: 0.5199 - ingredients_output_loss: 0.0148 - calorie_output_loss: 0.4142 - carbs_output_loss: 0.0521 - protein_output_loss: 0.0182 - fat_output_loss: 0.0454 - category_output_acc: 0.8499 - category_output_precision: 0.9238 - category_output_recall: 0.7867 - ingredients_output_precision: 0.8941 - ingredients_output_recall: 0.6227 - calorie_output_MAE: 0.4142 - carbs_output_MAE: 0.0521 - protein_output_MAE: 0.0182 - fat_output_MAE: 0.0454 - val_loss: 1.6445 - val_category_output_loss: 1.0727 - val_ingredients_output_loss: 0.0160 - val_calorie_output_loss: 0.4398 - val_carbs_output_loss: 0.0522 - val_protein_output_loss: 0.0179 - val_fat_output_loss: 0.0459 - val_category_output_acc: 0.7276 - val_category_output_precision: 0.8296 - val_category_output_recall: 0.6745 - val_ingredients_output_precision: 0.8700 - val_ingredients_output_recall: 0.6009 - val_calorie_output_MAE: 0.4398 - val_carbs_output_MAE: 0.0522 - val_protein_output_MAE: 0.0179 - val_fat_output_MAE: 0.0459 - lr: 1.0000e-05 - 921s/epoch - 3s/step
# Epoch 20/20
# 334/334 - 912s - loss: 1.0527 - category_output_loss: 0.5093 - ingredients_output_loss: 0.0147 - calorie_output_loss: 0.4133 - carbs_output_loss: 0.0520 - protein_output_loss: 0.0182 - fat_output_loss: 0.0453 - category_output_acc: 0.8545 - category_output_precision: 0.9275 - category_output_recall: 0.7915 - ingredients_output_precision: 0.8959 - ingredients_output_recall: 0.6238 - calorie_output_MAE: 0.4133 - carbs_output_MAE: 0.0520 - protein_output_MAE: 0.0182 - fat_output_MAE: 0.0453 - val_loss: 1.6410 - val_category_output_loss: 1.0699 - val_ingredients_output_loss: 0.0160 - val_calorie_output_loss: 0.4393 - val_carbs_output_loss: 0.0521 - val_protein_output_loss: 0.0179 - val_fat_output_loss: 0.0459 - val_category_output_acc: 0.7278 - val_category_output_precision: 0.8297 - val_category_output_recall: 0.6745 - val_ingredients_output_precision: 0.8707 - val_ingredients_output_recall: 0.6017 - val_calorie_output_MAE: 0.4393 - val_carbs_output_MAE: 0.0521 - val_protein_output_MAE: 0.0179 - val_fat_output_MAE: 0.0459 - lr: 1.0000e-05 - 912s/epoch - 3s/step

# %%
import shutil
import os
source_directory = '/content/food_v5/main'
destination_directory = '/content/drive/MyDrive/output2'

if not os.path.exists(destination_directory):
    os.makedirs(destination_directory)

shutil.copytree(source_directory, destination_directory, dirs_exist_ok=True)

print(f"Files from {source_directory} have been copied to {destination_directory}")
# Out:
# Files from /content/food_v5/main have been copied to /content/drive/MyDrive/output2
